# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import datetime
import re
import json

# %%
# for test purposes->
#fortune500_list=['Walmart']
#'Apple','Exxon Mobil','Booz Allen Hamilton']
# Top Fortune 500 of YR 2018 short list

#fortune500['Company Name'][:500].tolist

fortune500=pd.read_csv("fortune500list.csv")

# %%
fortune500_list=list(fortune500['Company Name'][:500])
fortune500_list
# Out:
# ['Walmart',
#  'Exxon Mobil',
#  'Berkshire Hathaway',
#  'Apple',
#  'UnitedHealth Group',
#  'McKesson',
#  'CVS Health',
#  'Amazon.com',
#  'AT&T',
#  'General Motors',
#  'Ford Motor',
#  'AmerisourceBergen',
#  'Chevron',
#  'Cardinal Health',
#  'Costco',
#  'Verizon',
#  'Kroger',
#  'General Electric',
#  'Walgreens Boots Alliance',
#  'JPMorgan Chase',
#  'Fannie Mae',
#  'Alphabet',
#  'Home Depot',
#  'Bank of America Corp.',
#  'Express Scripts Holding',
#  'Wells Fargo',
#  'Boeing',
#  'Phillips ',
#  'Anthem',
#  'Microsoft',
#  'Valero Energy',
#  'Citigroup',
#  'Comcast',
#  'IBM',
#  'Dell Technologies',
#  'State Farm Insurance Cos.',
#  'Johnson & Johnson',
#  'Freddie Mac',
#  'Target',
#  'Lowe’s',
#  'Marathon Petroleum',
#  'Procter & Gamble',
#  'MetLife',
#  'UPS',
#  'PepsiCo',
#  'Intel',
#  'DowDuPont',
#  'Archer Daniels Midland',
#  'Aetna',
#  'FedEx',
#  'United Technologies',
#  'Prudential Financial',
#  'Albertsons Cos.',
#  'Sysco',
#  'Disney',
#  'Humana',
#  'Pfizer',
#  'HP',
#  'Lockheed Martin',
#  'AIG',
#  'Centene',
#  'Cisco Systems',
#  'HCA Healthcare',
#  'Energy Transfer Equity',
#  'Caterpillar',
#  'Nationwide',
#  'Morgan Stanley',
#  'Liberty Mutual Insurance Group',
#  'New York Life Insurance',
#  'Goldman Sachs Group',
#  'American Airlines Group',
#  'Best Buy',
#  'Cigna',
#  'Charter Communications',
#  'Delta Air Lines',
#  'Facebook',
#  'Honeywell International',
#  'Merck',
#  'Allstate',
#  'Tyson Foods',
#  'United Continental Holdings',
#  'Oracle',
#  'Tech Data',
#  'TIAA',
#  'TJX',
#  'American Express',
#  'Coca-Cola',
#  'Publix Super Markets',
#  'Nike',
#  'Andeavor',
#  'World Fuel Services',
#  'Exelon',
#  'Massachusetts Mutual Life Insurance',
#  'Rite Aid',
#  'ConocoPhillips',
#  'CHS',
#  'M',
#  'Time Warner',
#  'General Dynamics',
#  'USAA',
#  'Capital One Financial',
#  'Deere',
#  'INTL FCStone',
#  'Northwestern Mutual',
#  'Enterprise Products Partners',
#  'Travelers Cos.',
#  'Hewlett Packard Enterprise',
#  'Philip Morris International',
#  'Twenty-First Century Fox',
#  'AbbVie',
#  'Abbott Laboratories',
#  'Progressive',
#  'Arrow Electronics',
#  'Kraft Heinz',
#  'Plains GP Holdings',
#  'Gilead Sciences',
#  'Mondelez International',
#  'Northrop Grumman',
#  'Raytheon',
#  'Macy’s',
#  'US Foods Holding',
#  'U.S. Bancorp',
#  'Dollar General',
#  'International Paper',
#  'Duke Energy',
#  'Southern',
#  'Marriott International',
#  'Avnet',
#  'Eli Lilly',
#  'Amgen',
#  'McDonald’s',
#  'Starbucks',
#  'Qualcomm',
#  'Dollar Tree',
#  'PBF Energy',
#  'Icahn Enterprises',
#  'Aflac',
#  'AutoNation',
#  'Penske Automotive Group',
#  'Whirlpool',
#  'Union Pacific',
#  'Southwest Airlines',
#  'ManpowerGroup',
#  'Thermo Fisher Scientific',
#  'Bristol-Myers Squibb',
#  'Halliburton',
#  'Tenet Healthcare',
#  'Lear',
#  'Cummins',
#  'Micron Technology',
#  'Nucor',
#  'Molina Healthcare',
#  'Fluor',
#  'Altria Group',
#  'Paccar',
#  'Hartford Financial Services',
#  'Kohl’s',
#  'Western Digital',
#  'Jabil',
#  'Community Health Systems',
#  'Visa',
#  'Danaher',
#  'Kimberly-Clark',
#  'AECOM',
#  'PNC Financial Services',
#  'CenturyLink',
#  'NextEra Energy',
#  'PG&E Corp.',
#  'Synnex',
#  'WellCare Health Plans',
#  'Performance Food Group',
#  'Sears Holdings',
#  'Synchrony Financial',
#  'CarMax',
#  'Bank of New York Mellon',
#  'Freeport-McMoRan',
#  'Genuine Parts',
#  'Emerson Electric',
#  'DaVita',
#  'Supervalu',
#  'Gap',
#  'General Mills',
#  'Nordstrom',
#  'Colgate-Palmolive',
#  'American Electric Power',
#  'XPO Logistics',
#  'Goodyear Tire & Rubber',
#  'Omnicom Group',
#  'CDW',
#  'Sherwin-Williams',
#  'PPG Industries',
#  'Texas Instruments',
#  'C.H. Robinson Worldwide',
#  'WestRock',
#  'Cognizant Technology Solutions',
#  'Newell Brands',
#  'CBS',
#  'Envision Healthcare',
#  'Monsanto',
#  'Aramark',
#  'Applied Materials',
#  'Waste Management',
#  'DISH Network',
#  'Illinois Tool Works',
#  'Lincoln National',
#  'HollyFrontier',
#  'CBRE Group',
#  'Textron',
#  'Ross Stores',
#  'Principal Financial',
#  'D.R. Horton',
#  'Marsh & McLennan',
#  'Devon Energy',
#  'AES',
#  'Ecolab',
#  'Land O’Lakes',
#  'Loews',
#  'Kinder Morgan',
#  'FirstEnergy',
#  'Occidental Petroleum',
#  'Viacom',
#  'PayPal Holdings',
#  'NGL Energy Partners',
#  'Celgene',
#  'Arconic',
#  'Kellogg',
#  'Las Vegas Sands',
#  'Stanley Black & Decker',
#  'Booking Holdings',
#  'Lennar',
#  'L Brands',
#  'DTE Energy',
#  'Dominion Energy',
#  'Reinsurance Group of America',
#  'J.C. Penney',
#  'Mastercard',
#  'BlackRock',
#  'Henry Schein',
#  'Guardian Life Ins. Co. of America',
#  'Stryker',
#  'Jefferies Financial Group',
#  'VF',
#  'ADP',
#  'Edison International',
#  'Biogen',
#  'United States Steel',
#  'Core-Mark Holding',
#  'Bed Bath & Beyond',
#  'Oneok',
#  'BB&T Corp.',
#  'Becton Dickinson',
#  'Ameriprise Financial',
#  'Farmers Insurance Exchange',
#  'First Data',
#  'Consolidated Edison',
#  'Parker-Hannifin',
#  'Anadarko Petroleum',
#  'Estee Lauder',
#  'State Street Corp.',
#  'Tesla',
#  'Netflix',
#  'Alcoa',
#  'Discover Financial Services',
#  'Praxair',
#  'CSX',
#  'Xcel Energy',
#  'Unum Group',
#  'Universal Health Services',
#  'NRG Energy',
#  'EOG Resources',
#  'Sempra Energy',
#  'Toys “R” Us',
#  'Group  Automotive',
#  'Entergy',
#  'Molson Coors Brewing',
#  'L Technologies',
#  'Ball',
#  'AutoZone',
#  'Murphy USA',
#  'MGM Resorts International',
#  'Office Depot',
#  'Huntsman',
#  'Baxter International',
#  'Norfolk Southern',
#  'salesforce.com',
#  'Laboratory Corp. of America',
#  'W.W. Grainger',
#  'Qurate Retail',
#  'Autoliv',
#  'Live Nation Entertainment',
#  'Xerox',
#  'Leidos Holdings',
#  'Corning',
#  'Lithia Motors',
#  'Expedia Group',
#  'Republic Services',
#  'Jacobs Engineering Group',
#  'Sonic Automotive',
#  'Ally Financial',
#  'LKQ',
#  'BorgWarner',
#  'Fidelity National Financial',
#  'SunTrust Banks',
#  'IQVIA Holdings',
#  'Reliance Steel & Aluminum',
#  'Nvidia',
#  'Voya Financial',
#  'CenterPoint Energy',
#  'eBay',
#  'Eastman Chemical',
#  'American Family Insurance Group',
#  'Steel Dynamics',
#  'Pacific Life',
#  'Chesapeake Energy',
#  'Mohawk Industries',
#  'Quanta Services',
#  'Advance Auto Parts',
#  'Owens & Minor',
#  'United Natural Foods',
#  'Tenneco',
#  'Conagra Brands',
#  'GameStop',
#  'Hormel Foods',
#  'Hilton Worldwide Holdings',
#  'Frontier Communications',
#  'Fidelity National Information Services',
#  'Public Service Enterprise Group',
#  'Boston Scientific',
#  'O’Reilly Automotive',
#  'Charles Schwab',
#  'Global Partners',
#  'PVH',
#  'Avis Budget Group',
#  'Targa Resources',
#  'Hertz Global Holdings',
#  'Calpine',
#  'Mutual of Omaha Insurance',
#  'Crown Holdings',
#  'Peter Kiewit Sons’',
#  'Dick’s Sporting Goods',
#  'PulteGroup',
#  'Navistar International',
#  'Thrivent Financial for Lutherans',
#  'DCP Midstream',
#  'Air Products & Chemicals',
#  'Veritiv',
#  'AGCO',
#  'Genworth Financial',
#  'Univar',
#  'News Corp.',
#  'SpartanNash',
#  'Westlake Chemical',
#  'Williams',
#  'Lam Research',
#  'Alaska Air Group',
#  'Jones Lang LaSalle',
#  'Anixter International',
#  'Campbell Soup',
#  'Interpublic Group',
#  'Dover',
#  'Zimmer Biomet Holdings',
#  'Dean Foods',
#  'Foot Locker',
#  'Eversource Energy',
#  'Alliance Data Systems',
#  'Fifth Third Bancorp',
#  'Quest Diagnostics',
#  'EMCOR Group',
#  'W.R. Berkley',
#  'WESCO International',
#  'Coty',
#  'WEC Energy Group',
#  'Masco',
#  'DXC Technology',
#  'Auto-Owners Insurance',
#  'Jones Financial (Edward Jones)',
#  'Liberty Media',
#  'Erie Insurance Group',
#  'Hershey',
#  'PPL',
#  'Huntington Ingalls Industries',
#  'Mosaic',
#  'J.M. Smucker',
#  'Delek US Holdings',
#  'Newmont Mining',
#  'Constellation Brands',
#  'Ryder System',
#  'National Oilwell Varco',
#  'Adobe Systems',
#  'LifePoint Health',
#  'Tractor Supply',
#  'Thor Industries',
#  'Dana',
#  'Weyerhaeuser',
#  'J.B. Hunt Transport Services',
#  'Darden Restaurants',
#  'Yum China Holdings',
#  'Blackstone Group',
#  'Berry Global Group',
#  'Builders FirstSource',
#  'Activision Blizzard',
#  'JetBlue Airways',
#  'Amphenol',
#  'A-Mark Precious Metals',
#  'Spirit AeroSystems Holdings',
#  'R.R. Donnelley & Sons',
#  'Harris',
#  'Expeditors Intl. of Washington',
#  'Discovery',
#  'Owens-Illinois',
#  'Sanmina',
#  'KeyCorp',
#  'American Financial Group',
#  'Oshkosh',
#  'Rockwell Collins',
#  'Kindred Healthcare',
#  'Insight Enterprises',
#  'Dr Pepper Snapple Group',
#  'American Tower',
#  'Fortive',
#  'Ralph Lauren',
#  'HRG Group',
#  'Ascena Retail Group',
#  'United Rentals',
#  'Casey’s General Stores',
#  'Graybar Electric',
#  'Avery Dennison',
#  'MasTec',
#  'CMS Energy',
#  'HD Supply Holdings',
#  'Raymond James Financial',
#  'NCR',
#  'Hanesbrands',
#  'Asbury Automotive Group',
#  'Citizens Financial Group',
#  'Packaging Corp. of America',
#  'Alleghany',
#  'Apache',
#  'Dillard’s',
#  'Assurant',
#  'Franklin Resources',
#  'Owens Corning',
#  'Motorola Solutions',
#  'NVR',
#  'Rockwell Automation',
#  'TreeHouse Foods',
#  'Wynn Resorts',
#  'Olin',
#  'American Axle & Manufacturing',
#  'Old Republic International',
#  'Chemours',
#  'iHeartMedia',
#  'Ameren',
#  'Arthur J. Gallagher',
#  'Celanese',
#  'Sealed Air',
#  'UGI',
#  'Realogy Holdings',
#  'Burlington Stores',
#  'Regions Financial',
#  'AK Steel Holding',
#  'Securian Financial Group',
#  'S&P Global',
#  'Markel',
#  'TravelCenters of America',
#  'Conduent',
#  'M&T Bank Corp.',
#  'Clorox',
#  'AmTrust Financial Services',
#  'KKR',
#  'Ulta Beauty',
#  'Yum Brands',
#  'Regeneron Pharmaceuticals',
#  'Windstream Holdings',
#  'Magellan Health',
#  'Western & Southern Financial',
#  'Intercontinental Exchange',
#  'Ingredion',
#  'Wyndham Destinations',
#  'Toll Brothers',
#  'Seaboard',
#  'Booz Allen Hamilton',
#  'First American Financial',
#  'Cincinnati Financial',
#  'Avon Products',
#  'Northern Trust',
#  'Fiserv',
#  'Harley-Davidson',
#  'Cheniere Energy',
#  'Patterson',
#  'Peabody Energy',
#  'ON Semiconductor',
#  'Simon Property Group',
#  'Western Union',
#  'NetApp',
#  'Polaris Industries',
#  'Pioneer Natural Resources',
#  'ABM Industries',
#  'Vistra Energy',
#  'Cintas']

# %%
now = datetime.datetime.now()
#div class="list-search-wrapper" data-reactid="
fortune_pg="http://www.fortune.com/fortune500/list/"
fortune_html = requests.get(fortune_pg)
fortune_soup = bs(fortune_html.text, 'html.parser')
fortune_list = fortune_soup.find_all('div')

# %%
# What do you want to search for?
what="python,+sql,+etl"

# %%
# Indeed query by company only to get company id from Indeed then apply that to second query
jobs = []
for co in fortune500_list:
    co=co.replace('&','')
    first_url_step="https://www.indeed.com/jobs?q="+ co.replace(" ",'+') +"&sort=date"
    print(first_url_step)
    html = requests.get(first_url_step)
    soup = bs(html.text, 'html.parser')
    try:
        jcid = (soup.find('span', {'class':'company'}).a['onmousedown'].split('jcid=')[-1].split("'")[0])
        print(soup.find('span', {'class':'company'}).a.text.replace("\n","").strip(), jcid)
    except:
        print("skipped: ",co)
    
    # Current date time object
    now = datetime.datetime.now()
    second_url_step="https://www.indeed.com/jobs?q="+ what + "&rbc=" + co.replace(" ",'+') + "&jcid=" + jcid + "&sort=date"
    print(second_url_step)
    html2 = requests.get(second_url_step)
    print(html2)
    next_soup = bs(html2.text, 'html.parser')
    all_jobs = next_soup.find_all('div', {'data-tn-component':"organicJob"})
    job_no = 0
    for result in all_jobs:
        #print(result)
        job_row = {}
        co_text = result.find('span', {'class':'company'})
        #print(co_text)
        try:
            job_row['jkid'] = result.h2.a['href'].split('?')[1].split('&')[0].split('jk=')[1]
            job_row['company'] = co_text.a.text.replace("\n","").strip()
            job_row['jcid'] = result.find('span', {'class':'company'}).a['onmousedown'].split('jcid=')[-1].split("'")[0]
            job_row['loc'] = result.find('span', {'class':'location'}).text
            job_row['job_no'] =  job_no + 1
            job_row['title'] = result.find('a', {'data-tn-element':'jobTitle'}).text
            job_row['desc'] = result.find('span', {'class':'summary'}).text.replace("\n","").strip()
            job_row['age'] = result.find('span', {'class':'date'}).text
            job_row['query_date'] = now.isoformat().split('T')[0]
            job_row['query_time'] = now.isoformat().split('T')[1].split('.')[0]
            jobs.append(job_row)
            job_no+=1
        except:
            print("skipped: ",co_text)
# Out:
# https://www.indeed.com/jobs?q=Walmart&sort=date
# Wal-mart c37d94a5a4e68054
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Walmart&jcid=c37d94a5a4e68054&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Exxon+Mobil&sort=date
# ExxonMobil 1ddb91d85c72e885
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Exxon+Mobil&jcid=1ddb91d85c72e885&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Berkshire+Hathaway&sort=date
# BH Media Group 7601c2041c118c1d
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Berkshire+Hathaway&jcid=7601c2041c118c1d&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Apple&sort=date
# Apple c1099851e9794854
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Apple&jcid=c1099851e9794854&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=UnitedHealth+Group&sort=date
# UnitedHealth Group d3d3520998346837
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=UnitedHealth+Group&jcid=d3d3520998346837&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=McKesson&sort=date
# McKesson a7c5036618407010
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=McKesson&jcid=a7c5036618407010&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=CVS+Health&sort=date
# CVS Health / CVS Pharmacy c34f74a40072f04b
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=CVS+Health&jcid=c34f74a40072f04b&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Amazon.com&sort=date
# Amazon.com fe2d21eef233e94a
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Amazon.com&jcid=fe2d21eef233e94a&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=ATT&sort=date
# AT&T 25b5166547bbf543
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=ATT&jcid=25b5166547bbf543&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=General+Motors&sort=date
# Smithfield Foods 47a15cde3c2472ae
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=General+Motors&jcid=47a15cde3c2472ae&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Ford+Motor&sort=date
# Henry Ford Health System fcee73a6346b7a5b
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Ford+Motor&jcid=fcee73a6346b7a5b&sort=date
# <Response [200]>
# skipped:  <span class="company">
# <a href="/cmp/Henry-Ford-Health-System" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=ebbcdfd1f9a76330&amp;jcid=fcee73a6346b7a5b')" rel="noopener" target="_blank">
#         Henry Ford Health System</a></span>
# https://www.indeed.com/jobs?q=AmerisourceBergen&sort=date
# AmerisourceBergen a6362e26eb1427c7
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=AmerisourceBergen&jcid=a6362e26eb1427c7&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Chevron&sort=date
# Chevron 9cf8e6c19900b0a8
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Chevron&jcid=9cf8e6c19900b0a8&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Cardinal+Health&sort=date
# Cardinal Health 87b328666e50453b
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Cardinal+Health&jcid=87b328666e50453b&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Costco&sort=date
# REDWOOD CITY COSTCO 15213f83480e7030
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Costco&jcid=15213f83480e7030&sort=date
# <Response [200]>
# skipped:  <span class="company">
# <a href="/cmp/Costco-Wholesale" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=a130e7fc327ac7c9&amp;jcid=4c9e240a1d46f683')" rel="noopener" target="_blank">
#         Costco Travel</a></span>
# https://www.indeed.com/jobs?q=Verizon&sort=date
# Verizon Wireless Premium Retailer c9bc3b7f2c6147d0
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Verizon&jcid=c9bc3b7f2c6147d0&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Kroger&sort=date
# Fred Meyer and Littman Jewelers 51df59ae498e8cc6
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Kroger&jcid=51df59ae498e8cc6&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=General+Electric&sort=date
# General Electric 0f2ee88943b9e35b
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=General+Electric&jcid=0f2ee88943b9e35b&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Walgreens+Boots+Alliance&sort=date
# Walgreens Boots Alliance 1054b3e3b84f3e04
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Walgreens+Boots+Alliance&jcid=1054b3e3b84f3e04&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=JPMorgan+Chase&sort=date
# JP Morgan Chase 11ba90543b779766
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=JPMorgan+Chase&jcid=11ba90543b779766&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Fannie+Mae&sort=date
# Fannie Mae 2231941280824ce7
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Fannie+Mae&jcid=2231941280824ce7&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Alphabet&sort=date
# skipped:  Alphabet
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Alphabet&jcid=2231941280824ce7&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Home+Depot&sort=date
# The Home Depot 82e58e9861d48566
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Home+Depot&jcid=82e58e9861d48566&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Bank+of+America+Corp.&sort=date
# skipped:  Bank of America Corp.
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Bank+of+America+Corp.&jcid=82e58e9861d48566&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Express+Scripts+Holding&sort=date
# Direct General 18e3515f732d31b6
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Express+Scripts+Holding&jcid=18e3515f732d31b6&sort=date
# <Response [200]>
# skipped:  <span class="company">
#         Direct General</span>
# skipped:  <span class="company">
#         Direct General</span>
# skipped:  <span class="company">
#         Direct General</span>
# skipped:  <span class="company">
#         Direct General</span>
# https://www.indeed.com/jobs?q=Wells+Fargo&sort=date
# Wells Fargo 78bbcd26e39621f5
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Wells+Fargo&jcid=78bbcd26e39621f5&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Boeing&sort=date
# BOEING edae4285faf6c2f0
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Boeing&jcid=edae4285faf6c2f0&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Phillips+&sort=date
# skipped:  Phillips
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Phillips+&jcid=edae4285faf6c2f0&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Anthem&sort=date
# Anthem, Inc. 31da63c4646feb82
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Anthem&jcid=31da63c4646feb82&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Microsoft&sort=date
# Microsoft 734cb5a01ee60f80
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Microsoft&jcid=734cb5a01ee60f80&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=
sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=United+Continental+Holdings&sort=date
# The Orvis Company 71724992373a13af
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=United+Continental+Holdings&jcid=71724992373a13af&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Oracle&sort=date
# Oracle cd22d01053af7669
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Oracle&jcid=cd22d01053af7669&sort=date
# <Response [200]>
# skipped:  <span class="company">
# <a href="/cmp/Oracle" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=6a576548ebb382a4&amp;jcid=cd22d01053af7669')" rel="noopener" target="_blank">
#         Oracle</a></span>
# https://www.indeed.com/jobs?q=Tech+Data&sort=date
# QuadraNet 21d03934e7f54695
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Tech+Data&jcid=21d03934e7f54695&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=TIAA&sort=date
# SMG 32eaf72b14533e63
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=TIAA&jcid=32eaf72b14533e63&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=TJX&sort=date
# Marshalls Inc d7665cecf7f01808
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=TJX&jcid=d7665cecf7f01808&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=American+Express&sort=date
# American Express f057e04c37cca134
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=American+Express&jcid=f057e04c37cca134&sort=date
# <Response [200]>
# skipped:  <span class="company">
#         American Express</span>
# https://www.indeed.com/jobs?q=Coca-Cola&sort=date
# The Coca-Cola Company 6bb4fc4a8a4cb4d9
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Coca-Cola&jcid=6bb4fc4a8a4cb4d9&sort=date
# <Response [200]>
# skipped:  <span class="company">
# <a href="/cmp/Coca--cola-Refreshments" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=4397860bcbde6881&amp;jcid=ddaaa3395612ab29')" rel="noopener" target="_blank">
#         Coca Cola Beverages Florida</a></span>
# https://www.indeed.com/jobs?q=Publix+Super+Markets&sort=date
# Publix Super Markets, Inc. 224f888adfa17269
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Publix+Super+Markets&jcid=224f888adfa17269&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Nike&sort=date
# NIKE INC e4a0ebc7ef5e730e
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Nike&jcid=e4a0ebc7ef5e730e&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Andeavor&sort=date
# Andeavor 72f58115e6e5ab2d
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Andeavor&jcid=72f58115e6e5ab2d&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=World+Fuel+Services&sort=date
# Textron Systems: Support Solutions fe5eab8cb20ec4b9
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=World+Fuel+Services&jcid=fe5eab8cb20ec4b9&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Exelon&sort=date
# Exelon Corporation edc3e0381f52a252
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Exelon&jcid=edc3e0381f52a252&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Massachusetts+Mutual+Life+Insurance&sort=date
# Guardian Life Insurance Company be86dcd6c4c7908c
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Massachusetts+Mutual+Life+Insurance&jcid=be86dcd6c4c7908c&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Rite+Aid&sort=date
# Rite Aid 70849576d4f74b24
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Rite+Aid&jcid=70849576d4f74b24&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=ConocoPhillips&sort=date
# skipped:  ConocoPhillips
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=ConocoPhillips&jcid=70849576d4f74b24&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=CHS&sort=date
# San Diego Zoo 0e9146214bc60876
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=CHS&jcid=0e9146214bc60876&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=M&sort=date
# Half Price Books, Records, Magazines, Inc. 0c204453bba87e86
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=M&jcid=0c204453bba87e86&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Time+Warner&sort=date
# Time Warner e93ea969c594e053
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Time+Warner&jcid=e93ea969c594e053&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=General+Dynamics&sort=date
# GNC - General Nutrition Centers 7142a62b2e553975
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=General+Dynamics&jcid=7142a62b2e553975&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=USAA&sort=date
# USAA 3a1edc2d763c4288
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=USAA&jcid=3a1edc2d763c4288&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Capital+One+Financial&sort=date
# skipped:  Capital One Financial
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Capital+One+Financial&jcid=3a1edc2d763c4288&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Deere&sort=date
# skipped:  Deere
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=
sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Western+Union&sort=date
# Commonwealth of PA Bureau of State Employment e18efbfc7bc12638
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Western+Union&jcid=e18efbfc7bc12638&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=NetApp&sort=date
# CSRA 0e18721ba57279e5
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=NetApp&jcid=0e18721ba57279e5&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Polaris+Industries&sort=date
# Polaris Industries aae866015a9997ca
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Polaris+Industries&jcid=aae866015a9997ca&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Pioneer+Natural+Resources&sort=date
# Cornell University 306f028923c9e104
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Pioneer+Natural+Resources&jcid=306f028923c9e104&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=ABM+Industries&sort=date
# Grainger 68bc43ebf2f50281
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=ABM+Industries&jcid=68bc43ebf2f50281&sort=date
# <Response [200]>
# skipped:  <span class="company">
# <a href="/cmp/Grainger" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=b836d607ce0dff5d&amp;jcid=68bc43ebf2f50281')" rel="noopener" target="_blank">
#         Grainger</a></span>
# https://www.indeed.com/jobs?q=Vistra+Energy&sort=date
# Vistra Corporate Services Company 372b73a51d3c61bb
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Vistra+Energy&jcid=372b73a51d3c61bb&sort=date
# <Response [200]>
# https://www.indeed.com/jobs?q=Cintas&sort=date
# Cintas 75dddf0a132694ba
# https://www.indeed.com/jobs?q=python,+sql,+etl&rbc=Cintas&jcid=75dddf0a132694ba&sort=date
# <Response [200]>

# %%
for line in soup.find_all('script', {"type":"text/javascript"}):
    print(line)
# Out:
# <script src="/s/0247a00/en_US.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#     if (typeof window['closureReadyCallbacks'] == 'undefined') {
#         window['closureReadyCallbacks'] = [];
#     }
#
#     function call_when_jsall_loaded(cb) {
#         if (window['closureReady']) {
#             cb();
#         } else {
#             window['closureReadyCallbacks'].push(cb);
#         }
#     }
# </script>
# <script src="/s/12d9950/jobsearch-all-compiled.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# var searchUID = '1cr14i0ld0k4n003';
# var tk = '1cr14i0ld0k4n003';
#
# var loggedIn = false;
# var dcmPayload = 'jobse0;jobal0;viewj0;savej0;6927552';
# var myindeed = true;
# var userEmail = '';
# var tellFriendEmail = '';
# var globalLoginURL = 'https:\/\/www.indeed.com\/account\/login?dest=%2Fjobs%3Fq%3DWalmart%26sort%3Ddate';
# var globalRegisterURL = 'https:\/\/www.indeed.com\/account\/register?dest=%2Fjobs%3Fq%3DWalmart%26sort%3Ddate';
# var searchKey = '434f580506c9a59c';
# var searchState = 'q=Walmart&amp;sort=date';
# var searchQS = 'q=Walmart&sort=date';
# var eventType = 'jobsearch';
# var locale = 'en_US';
# function clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf('&jsa='); if (si > 0) return; var jsh = hr + '&tk=1cr14i0ld0k4n003&jsa=6685'; a.href = jsh; }
# function sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf('&oc=1'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }
# function sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + '&oc=1&sal='+sal; }
# function ptk(st,p) {document.cookie = 'PTK="tk=1cr14i0ld0k4n003&type=jobsearch&subtype='+st+(p?'&'+p:'')+'"; path=/';}
# function rbptk(st, c, p) { ptk(st, 'cat='+c+(p?'&p='+p:''));}
# </script>
# <script type="text/javascript">
# 	function loadJSAsync( ) {
# 		for ( var i = 0; i < arguments.length; i++ ) {
# 			var url = arguments[i];
# 			(function() {
# 				var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
# 				s.async = true;
# 				s.src = url;
# 				el.parentNode.insertBefore(s, el);
# 			})();
# 		}
# 	}
# </script>
# <script type="text/javascript">
#     var dcmPayload = 'jobse0;jobal0;viewj0;savej0;6927552';
#     var indeedCsrfToken = 'hMkG2yomuFGWM0PgyvYC2VpPAGporQ5Q';
#     var hashedCsrfToken = '9cb3a8acdde53653734c82152f1fae9b';
# </script>
# <script type="text/javascript">
#      createTabBar('1cr14i0ld0k4n003');
#    </script>
# <script type="text/javascript">
#
# new AcController('where_ac', 'where_container', 'where', 'acdiv', 'acdiv_list',
#     '/rpc/suggest?from=serp&tk=1cr14i0ld0k4n003&version=2', 'l', true);
#
# new AcController('what_ac', 'what_container', 'what', 'what_acdiv', 'what_acdiv_list',
#     '/rpc/suggest?what=true&from=serp&tk=1cr14i0ld0k4n003&version=2', 'q', true);
# </script>
# <script type="text/javascript">
# function rclk(el,jobdata,oc,sal) { var ocstr = oc ? '&onclick=1' : ''; document.cookie='RCLK="jk='+jobdata.jk+'&tk=1cr14i0ld0k4n003&from=web&rd='+jobdata.rd+'&qd=7tdTJLF8oc4dPpT7T_zGvFQbwGjWQw4pmicCOZaSXLaJvBj_J7fst03gqxN-tXS_2sNyA4OBmWz_ezz9IqYVHh-AY6N_VKVPXqPmXRtPnIawwd-AKTAePLHMXJ56TZmZ&ts=1540857856685&sal='+sal+ocstr+'"; path=/'; return true;}
#
# function vjrclk(jk, qd, rd, oc, vjk, vjtk, jobsearchTk) {
#   var ocstr = oc ? '&onclick=1' : '';
#   var jobsearchTk = jobsearchTk ? jobsearchTk : '';
#   document.cookie = 'RCLK="jk=' + jk + '&vjtk=' + vjtk + '&jobsearchTk=' + jobsearchTk + '&rd=' + rd + '&qd=' + qd + '&ts=' + new Date().getTime() + ocstr + '"; path=/';
#   return true;
# }
#
# var resumePopover;
# function updateResumePromoCookie(event) {
#     var isSpecialKey = event.ctrlKey || event.metaKey || event.shiftKey;
#     if (window['resumePopoverShowValue'] && !isSpecialKey) {
#         if (!resumePopover) {
#             var setYearExpiration = true;
#             resumePopover = new ResumePopover('1cr14i0ld0k4n003', '1cr14i0l60k4n000', setYearExpiration);
#         }
#
#         resumePopover.updatePopoverCookieValue();
#         if (false) {
#             resumePopover.logConditionMet();
#         }
#     }
#     return true;
# }
# function zrprclk(el,jobdata,oc) { var ocstr = oc ? '&onclick=1' : ''; document.cookie='RCLK="jk='+jobdata.jk+'&tk=1cr14i0ld0k4n003&from=reconzrp&rd='+jobdata.rd+'&qd=7tdTJLF8oc4dPpT7T_zGvFQbwGjWQw4pmicCOZaSXLaJvBj_J7fst03gqxN-tXS_2sNyA4OBmWz_ezz9IqYVHh-AY6N_VKVPXqPmXRtPnIawwd-AKTAePLHMXJ56TZmZ&ts=1540857856685'+ocstr+'"; path=/'; return true;}
# function prjbottomclk(el,jobdata,oc) { var ocstr = oc ? '&onclick=1' : ''; document.cookie='RCLK="jk='+jobdata.jk+'&tk=1cr14i0ld0k4n003&from=reconserp&rd='+jobdata.rd+'&qd=7tdTJLF8oc4dPpT7T_zGvFQbwGjWQw4pmicCOZaSXLaJvBj_J7fst03gqxN-tXS_2sNyA4OBmWz_ezz9IqYVHh-AY6N_VKVPXqPmXRtPnIawwd-AKTAePLHMXJ56TZmZ&ts=1540857856685'+ocstr+'"; path=/'; return true;}
#
#
# var jobmap = {};
#
# jobmap[0]= {jk:'0e497ba2460b0c22',efccid: 'eacc908d242186c8',srcid:'177b6bba7da5910c',cmpid:'c37d94a5a4e68054',num:'0',srcname:'Indeed',cmp:'Wal-mart',cmpesc:'Wal-mart',cmplnk:'/jobs?q=Wal-mart',loc:'Sanford, ME',country:'US',zip:'',city:'Sanford',title:'Truck Unloader\/Stocker',locid:'f6a7868145d7c7a6',rd:'2WKP5Dncumetl6uQHWBI39Vz1Ky80Z5BJGSxDfkAa-QDGZuvwJY1uWV9p_YiLmK2'};
#
# jobmap[1]= {jk:'d525b341ac1c0e85',efccid: 'eacc908d242186c8',srcid:'2704a3cce3b65a0b',cmpid:'822bc5d9a49270ea',num:'1',srcname:'Indeed',cmp:'Walmart',cmpesc:'Walmart',cmplnk:'/q-Walmart-jobs.html',loc:'Westminster, CA 92683',country:'US',zip:'92683',city:'Westminster',title:'Pharmacy Cashier',locid:'599360af92d6396b',rd:'LdTfyXn3BJUQ3DP1gWsaH7N0veaqHAGN0v4eLVCKA8sDGZuvwJY1uWV9p_YiLmK2'};
#
# jobmap[2]= {jk:'a986e8e14c622d4b',efccid: 'eacc908d242186c8',srcid:'0c442c026f790d44',cmpid:'ca202dbd481c670f',num:'2',srcname:'Indeed',cmp:'Huntley Wal-Mart',cmpesc:'Huntley Wal-Mart',cmplnk:'/jobs?q=Huntley+Wal-Mart',loc:'Huntley, IL 60142',country:'US',zip:'60142',city:'Huntley',title:'O\/N Cashier (10pm-7am)',locid:'6c465b19b37c9e35',rd:'ksNjx-mCCxTfpBxRk4GxMaSg8Uqs9Kcmo3nzF782qG8DGZuvwJY1uWV9p_YiLmK2'};
#
# jobmap[3]= {jk:'cf43bb1b0a848bd3',efccid: 'eacc908d242186c8',srcid:'0c442c026f790d44',cmpid:'ca202dbd481c670f',num:'3',srcname:'Indeed',cmp:'Huntley Wal-Mart',cmpesc:'Huntley Wal-Mart',cmplnk:'/jobs?q=Huntley+Wal-Mart',loc:'Huntley, IL 60142',country:'US',zip:'60142',city:'Huntley',title:'O\/N Stocker (10pm-7am)',locid:'6c465b19b37c9e35',rd:'b51lnbclQQLZ1hYs6VDb6la8YIjbvzxxenjJxiEia9kDGZuvwJY1uWV9p_YiLmK2'};
#
# jobmap[4]= {jk:'84eb798711141c68',efccid: 'eacc908d242186c8',srcid:'9f648a43840e620a',cmpid:'2e384723c1d2e8ea',num:'4',srcname:'Indeed',cmp:'Walmart 3360',cmpesc:'Walmart 3360',cmplnk:'/q-Walmart-3360-jobs.html',loc:'Chandler, AZ',country:'US',zip:'',city:'Chandler',title:'Fabrics and Crafts Associate',locid:'cab65b76f64b42b9',rd:'vV1ywF_BeuSvqZv0gbug_icA1e8-7yQqtgV6q61_gssDGZuvwJY1uWV9p_YiLmK2'};
#
# jobmap[5]= {jk:'d980ee2b24c8b8ec',efccid: 'eacc908d242186c8',srcid:'0c442c026f790d44',cmpid:'ca202dbd481c670f',num:'5',srcname:'Indeed',cmp:'Huntley Wal-Mart',cmpesc:'Huntley Wal-Mart',cmplnk:'/jobs?q=Huntley+Wal-Mart',loc:'Huntley, IL 60142',country:'US',zip:'60142',city:'Huntley',title:'Cap 2 Associate (1pm-10 pm or 2pm- 11pm)',locid:'6c465b19b37c9e35',rd:'m1uUTzEIhGNn7h7WHEX1s6Hi5NhY5EyYfIAKhJq3iZwDGZuvwJY1uWV9p_YiLmK2'};
#
# jobmap[6]= {jk:'ba6bc56de739519d',efccid: 'eacc908d242186c8',srcid:'0c442c026f790d44',cmpid:'ca202dbd481c670f',num:'6',srcname:'Indeed',cmp:'Huntley Wal-Mart',cmpesc:'Huntley Wal-Mart',cmplnk:'/jobs?q=Huntley+Wal-Mart',loc:'Huntley, IL 60142',country:'US',zip:'60142',city:'Huntley',title:'Cap 1 Associate (4am-1pm)',locid:'6c465b19b37c9e35',rd:'fzmDV2NONvSY9hUwu9yCT_jsQuNMIbojve_UhFEB7bEDGZuvwJY1uWV9p_YiLmK2'};
#
# jobmap[7]= {jk:'91ea3ccb294fcf90',efccid: 'eacc908d242186c8',srcid:'891abfd45c236855',cmpid:'822bc5d9a49270ea',num:'7',srcname:'Indeed',cmp:'Walmart',cmpesc:'Walmart',cmplnk:'/q-Walmart-jobs.html',loc:'Lexington, NC',country:'US',zip:'',city:'Lexington',title:'Pharmacy Technician',locid:'0132fe6056d384e8',rd:'AIC5B1NZEYecQ3bNq-c_eAxwWw8f1NhMIuElyCLzTuoDGZuvwJY1uWV9p_YiLmK2'};
#
# jobmap[8]= {jk:'edc9e9d31aea0d46',efccid: 'eacc908d242186c8',srcid:'9f648a43840e620a',cmpid:'2e384723c1d2e8ea',num:'8',srcname:'Indeed',cmp:'Walmart 3360',cmpesc:'Walmart 3360',cmplnk:'/q-Walmart-3360-jobs.html',loc:'Chandler, AZ',country:'US',zip:'',city:'Chandler',title:'Deli Clerk\/Cook',locid:'cab65b76f64b42b9',rd:'4END045ptKKmHngt72SuiGkt93__szdaV9zs1rOYyNMDGZuvwJY1uWV9p_YiLmK2'};
#
# jobmap[9]= {jk:'0d52da0030656c20',efccid: 'eacc908d242186c8',srcid:'329dd2e4e6dcce0f',cmpid:'822bc5d9a49270ea',num:'9',srcname:'Indeed',cmp:'Walmart',cmpesc:'Walmart',cmplnk:'/q-Walmart-jobs.html',loc:'Seabrook, NH',country:'US',zip:'',city:'Seabrook',title:'Inventory Associate',locid:'5a36103d22ee6a91',rd:'0Pmsoov30oFk_hjTcso-wQoWupQROfE-ZOjfNRcmY5MDGZuvwJY1uWV9p_YiLmK2'};
# </script>
# <script type="text/javascript">
#     window['ree'] = "pdsssps";
#     window['jas'] = "KKrV7W0Oe";
# </script>
# <script type="text/javascript">
#     function setRefineByCookie(refineByTypes) {
#         var expires = new Date();
#         expires.setTime(expires.getTime() + (10 * 1000));
#         for (var i = 0; i < refineByTypes.length; i++) {
#             setCookie(refineByTypes[i], "1", expires);
#         }
#     }
# </script>
# <script type="text/javascript">
#             window['sjl'] = "PYVVDKDCO8i";
#         </script>
# <script type="text/javascript">
# function ptk(st,p) {
#   document.cookie = 'PTK="tk=&type=jobsearch&subtype=' + st + (p ? '&' + p : '')
#      + (st == 'pagination' ? '&fp=1' : '')
#     +'"; path=/';
# }
# </script>
# <script type="text/javascript">
# function pclk(event) {
#   var evt = event || window.event;
#   var target = evt.target || evt.srcElement;
#   var el = target.nodeType == 1 ? target : target.parentNode;
#   var tag = el.tagName.toLowerCase();
#   if (tag == 'span' || tag == 'a') {
#     ptk('pagination');
#   }
#   return true;
# }
# function addPPUrlParam(obj) {
#   var pp = obj.getAttribute('data-pp');
#   var href = obj.getAttribute('href');
#   if (pp && href) {
#     obj.setAttribute('href', href + '&pp=' + pp);
#   }
# }
# </script>
# <script type="text/javascript">
# 	var addAlertFormSubmit = function() {
# 		var email = document.getElementById('alertemail').value;
# 		var verified = document.getElementById('alertverified').value;
# 		var recJACheckbox = document.getElementById('recjobalert');
# 		var tacCheckbox = document.getElementById('termsandconditionscheckbox');
# 		var recjobalertchecked = recJACheckbox ? recJACheckbox.checked : false;
# 		var termsandconditionschecked = tacCheckbox ? tacCheckbox.checked : false;
#
# 		return addalertdelegate(
# 			'Walmart',
# 			'',
# 			'fccId%3Deacc908d242186c8',
# 			email,
# 			'1cr14i0ld0k4n003',
# 			verified,
# 			true,
# 			'661982',
# 			'US',
# 			'9cb3a8acdde53653734c82152f1fae9b',
# 			recjobalertchecked,
# 			false,
# 			termsandconditionschecked,
# 			true
# 		);
# 	}
# </script>
# <script type="text/javascript">usBindSalaryWidgetLoggingNew();</script>
# <script id="jaFloatScript" type="text/javascript">
#       initFloatingBoxes("#jobalertswrapper, #related-searches.related_searches_sticky");
#     </script>
# <script type="text/javascript">
#         function onClickResumePopoverPromo(uploadLink) {
#             var setYearExpiration = true;
#             var resumePopover = new ResumePopover('1cr14i0ld0k4n003', '1cr14i0l60k4n000', setYearExpiration);
#             resumePopover.onClickPromo(uploadLink);
#             return true;
#         }
#     </script>
# <script type="text/javascript">
#         window['resumePopoverShowValue'] = '1';
#     </script>
# <script type="text/javascript">
#         vjsExhibitionModel.initialize();
#         if (typeof bindAndRender !== 'undefined' && typeof bindAndRender === 'function') {
#             bindAndRender.apply();
#
#         }
#         if (typeof bindKeyAndRenderRecommended !== 'undefined' && typeof bindKeyAndRenderRecommended === 'function') {
#             bindKeyAndRenderRecommended.apply();
#         }
#     </script>
# <script type="text/javascript">
#                                 var jobsProductLink = document.getElementById('jobs_product_link');
#                                 </script>
# <script type="text/javascript">if(null !== call_when_jsall_loaded) {call_when_jsall_loaded(function() {if(!!window.logPromoImpression) {window.logPromoImpression('trk.origin=jobsearch&trk.variant=FooterGrayBelow&trk.pos=below&trk.tk=1cr14i0ld0k4n003', 'resume');}})}</script>
# <script type="text/javascript">
#         function sm_cv_tag(activityId) {
#             var ebRand = Math.random()+'';
#             ebRand = ebRand * 1000000;
#
#             var tagContainer = document.body.appendChild(document.createElement("div"));
#             tagContainer.style.position="absolute";
#             tagContainer.style.top="0";
#             tagContainer.style.left="0";
#             tagContainer.style.width="1px";
#             tagContainer.style.height="1px";
#             tagContainer.style.display="none";
#
#             var jsTag = document.createElement('script');
#             jsTag.src = '//bs.serving-sys.com/Serving/ActivityServer.bs?cn=as&ActivityID=' + activityId + '&rnd=' + ebRand;
#             jsTag.setAttribute('crossorigin', 'anonymous');
#             jsTag.style.width="1px";
#             jsTag.style.height="1px";
#             jsTag.style.border="0";
#             jsTag.async = 1;
#
#             var noScript = document.createElement("noscript");
#             var noScriptText = '<img width="1" height="1" style="border:0" src="//bs.serving-sys.com/Serving/ActivityServer.bs?cn=as&ActivityID=' + activityId + '&ns=1"/>';
#
#             // IE less than 9 and RCs do not support innerHTML on some DOM elements, but supports .text for it
#             if (((typeof noScript.canHaveHTML) === "boolean") && (noScript.canHaveHTML === false)) { // canHaveHTML only exists for IE
#                 noScript.text = noScriptText;
#             } else {
#                 noScript.innerHTML = noScriptText;
#             }
#
#             tagContainer.appendChild(jsTag);
#             tagContainer.appendChild(noScript);
#         }
#     </script>
# <script type="text/javascript">
# <!--
# logJSVPing('jsv', '1cr14i0ld0k4n003');
# function jsall_loaded() {
#
#
#     initProcessLeftoverDwellEntries();
#
#     detectBrowserState('jobsearch', '1cr14i0ld0k4n003');
#
#     initLogTiming('jobsearch', '1cr14i0ld0k4n003');
#
#     attachSjBlock('');
#     attachJaBlock('');
# }
# if (window['closureReady'] === true) {
#     jsall_loaded();
# }
# //-->
# </script>
# <script type="text/javascript">
# PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
# PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 5, 'loggedIn', 'false', 3];
# </script>
# <script type="text/javascript">
#         var ga_domains = [];
#         ga_domains.push('indeed.co.in');ga_domains.push('indeed.lu');ga_domains.push('indeed.fr');ga_domains.push('indeed.de');ga_domains.push('indeed.com.br');ga_domains.push('indeed.co.uk');ga_domains.push('indeed.hk');ga_domains.push('indeed.fi');ga_domains.push('indeed.pt');ga_domains.push('indeed.jp');ga_domains.push('indeed.com');ga_domains.push('indeed.com.sg');ga_domains.push('indeed.nl');ga_domains.push('indeed.com.pk');ga_domains.push('indeed.cl');ga_domains.push('indeed.es');ga_domains.push('indeed.co.ve');ga_domains.push('indeed.ae');ga_domains.push('indeed.com.mx');ga_domains.push('indeed.com.my');ga_domains.push('indeed.ch');ga_domains.push('indeed.com.co');ga_domains.push('indeed.com.ph');ga_domains.push('indeed.co.za');ga_domains.push('indeed.ie');ga_domains.push('indeed.com.au');ga_domains.push('indeed.ca');ga_domains.push('indeed.com.pe');
#
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r;
#             i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date();
#             a = s.createElement(o),
#                     m = s.getElementsByTagName(o)[0];
#             a.async = 1;
#             a.src = g;
#             m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#         var ga = ga || [];
#         ga('create', 'UA-90780-1', 'auto', {
#             'allowLinker': true
#         });
#         ga('require', 'linkid');
#         ga('require', 'linker');
#         ga('linker:autoLink', ga_domains, false, true);
#         ga('require', 'displayfeatures');
#         ga('send', 'pageview');
#
#
#         (function () {
#             if (window.PENDING_ANALYTICS_VARS && window.PENDING_ANALYTICS_VARS.length > 0) {
#                 for (var i in PENDING_ANALYTICS_VARS) {
#                     ga('set', PENDING_ANALYTICS_VARS[i][2], PENDING_ANALYTICS_VARS[i][3]);
#                 }
#             }
#         })();
#     </script>

# %%
soup.find('span', {'class':'company'}).a['href'].split('/')[2]

# %%
soup.find('span', {'class':'company'})

# %%
next_soup.find('div', {'data-tn-component':"organicJob"}).h2.a['href'].split('?')[1].split('&')[0].split('jk=')[1]

# %%
jobs
# Out:
# [{'jkid': '1b40383fd862d403',
#   'company': 'Walmart',
#   'jcid': '822bc5d9a49270ea',
#   'loc': 'Bentonville, AR 72712',
#   'job_no': 1,
#   'title': 'Business Intelligence Analyst -LEG',
#   'desc': '2 years experience with ETL, data modeling, SQL, and programming languages such as Python and R. Analyzes and interprets third-party spending, case resolutions,...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:18'},
#  {'jkid': '27ec2b40b1200fe2',
#   'company': 'Walmart',
#   'jcid': '822bc5d9a49270ea',
#   'loc': 'San Bruno, CA 94066',
#   'job_no': 2,
#   'title': 'Product Analytics Manager',
#   'desc': 'Fluency in SQL, as well as an understanding of statistical analysis, and common pitfalls of data analysis....',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:18'},
#  {'jkid': 'a3747a644aa53898',
#   'company': 'Walmart',
#   'jcid': '822bc5d9a49270ea',
#   'loc': 'Bentonville, AR 72712',
#   'job_no': 3,
#   'title': 'Software Engineer III',
#   'desc': "Position Description As a Software Engineer III for Walmart Labs, you'll be responsible for large-scale, e-commerce Web applications development, tools...",
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:18'},
#  {'jkid': '25492a3d97275785',
#   'company': 'Walmart',
#   'jcid': '822bc5d9a49270ea',
#   'loc': 'Sunnyvale, CA',
#   'job_no': 4,
#   'title': 'Search/Relevance - Staff Data Scientist',
#   'desc': 'Position Description In this role you will · Act as a thought leader to identify right problems to solve for our customers · Design and implement state of...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:18'},
#  {'jkid': '47a8e7b1fc47f6a7',
#   'company': 'Walmart',
#   'jcid': '822bc5d9a49270ea',
#   'loc': 'Sunnyvale, CA',
#   'job_no': 5,
#   'title': 'Staff Software Engineer',
#   'desc': "Experience in RESTful Services, RDBMS, NoSql, Python, NodeJs, AngularJS, Java. Come join an organization where you'll get to work as part of a world-class team,...",
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:18'},
#  {'jkid': '69fb8ae77baea3c0',
#   'company': 'Walmart',
#   'jcid': '822bc5d9a49270ea',
#   'loc': 'Reston, VA',
#   'job_no': 6,
#   'title': 'Sr Software Engineer-Tchnlgy',
#   'desc': '3 years experience with SQL Server 2008 or related program. JavaScript, CSS, XML, XHTML, HTML, SQL/ T-SQL, Core Java, Node.js, React.Js, Angular JS, NodeJS,...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:18'},
#  {'jkid': '56876f400ca02c07',
#   'company': 'Walmart',
#   'jcid': '822bc5d9a49270ea',
#   'loc': 'Sunnyvale, CA',
#   'job_no': 7,
#   'title': 'Senior Director, Change Management & Communications',
#   'desc': '9 years experience with SQL and relational databases (for example, DB2, Oracle, SQL Server). Consults with business stakeholders on data-based insights....',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:18'},
#  {'jkid': '64efb70b479d8044',
#   'company': 'Walmart',
#   'jcid': '822bc5d9a49270ea',
#   'loc': 'Sunnyvale, CA',
#   'job_no': 8,
#   'title': 'Senior Software Engineer',
#   'desc': "Experience in RESTful Services, RDBMS, NoSql, Python, NodeJs, AngularJS, Java. Come join an organization where you'll get to work as part of a world-class team,...",
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:18'},
#  {'jkid': '6eb9562c992b51b4',
#   'company': 'Walmart',
#   'jcid': '822bc5d9a49270ea',
#   'loc': 'Bentonville, AR 72712',
#   'job_no': 9,
#   'title': 'Software Engineer 3-Tchnlgy',
#   'desc': '5 years experience writing SQL queries in a database platform (for example, Oracle, DB2, Teradata, SQL Server)....',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:18'},
#  {'jkid': 'a6e6a0b57bcd491a',
#   'company': 'Walmart',
#   'jcid': '822bc5d9a49270ea',
#   'loc': 'Thomasville, GA 31792',
#   'job_no': 10,
#   'title': 'Sr. Manager - Plant Controller (Thomasville, GA)',
#   'desc': '1 year experience with financial software (for example, SAP, ERP, Essbase, SQL). Communicates accounting impacts, issues, and strategic directions....',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:18'},
#  {'jkid': 'aa0e47857ea36d4a',
#   'company': 'ExxonMobil',
#   'jcid': '1ddb91d85c72e885',
#   'loc': 'Houston, TX 77046 (Montrose area)',
#   'job_no': 1,
#   'title': 'Energy Components Analyst',
#   'desc': 'Tieto’s Energy Components (EC) application is used throughout the ExxonMobil Upstream business to support Volumetric Allocation and Entitlements workflows....',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:19'},
#  {'jkid': 'b2d29fb026beb382',
#   'company': 'ExxonMobil',
#   'jcid': '1ddb91d85c72e885',
#   'loc': 'Houston, TX 77046 (Montrose area)',
#   'job_no': 2,
#   'title': 'Mathematical Optimization Research Scientist',
#   'desc': '• Expert in at least one major programming language (C/C++, C#, Java, Python, etc.). ExxonMobil is looking for a mathematical optimization scientist with...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:19'},
#  {'jkid': '4720583a22ff3e47',
#   'company': 'ExxonMobil',
#   'jcid': '1ddb91d85c72e885',
#   'loc': 'Houston, TX 77046 (Montrose area)',
#   'job_no': 3,
#   'title': 'Research Data Scientist',
#   'desc': 'Experience in Python, MATLAB, or R is required. Research Data Scientist....',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:19'},
#  {'jkid': '30499d1f22003c3c',
#   'company': 'ExxonMobil',
#   'jcid': '1ddb91d85c72e885',
#   'loc': 'Houston, TX 77046 (Montrose area)',
#   'job_no': 4,
#   'title': 'Law Application Support Analyst',
#   'desc': 'Visual Studio .NET, SQL Server Management Studio, SQL Server Data Tools. SQL Server (ETL, Development in Stored Procedures / Trigger, working with large amount...',
#   'age': '4 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:19'},
#  {'jkid': '40a226b5018304de',
#   'company': 'ExxonMobil',
#   'jcid': '1ddb91d85c72e885',
#   'loc': 'Houston, TX 77046 (Montrose area)',
#   'job_no': 5,
#   'title': 'XTO IT Production Accounting Analyst',
#   'desc': 'Accounting, Database, SQL, Finance, Technology. Perform complex ad-hoc data extracts using MS SQL. Proficient with MS SQL database query optimization, in-depth...',
#   'age': '6 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:19'},
#  {'jkid': '43a35bd226895b7d',
#   'company': 'ExxonMobil',
#   'jcid': '1ddb91d85c72e885',
#   'loc': 'Houston, TX 77046 (Montrose area)',
#   'job_no': 6,
#   'title': 'Interoperability Engineer',
#   'desc': 'Understanding ETL and SLT jobs/coding. Experience developing ETL architecture, principles and standards. 5+ years experience with ETL and SLT coding....',
#   'age': '6 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:19'},
#  {'jkid': '3e9e06379559febd',
#   'company': 'ExxonMobil',
#   'jcid': '1ddb91d85c72e885',
#   'loc': 'Houston, TX 77046 (Montrose area)',
#   'job_no': 7,
#   'title': 'XTO IT Business Analyst',
#   'desc': 'Proficient with SQL Server and Oracle. Business Analyst, Database, Oracle, SQL, Finance, Technology. Provide technical support, data management, end-user...',
#   'age': '6 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:19'},
#  {'jkid': '9931d8e20ddffbf7',
#   'company': 'ExxonMobil',
#   'jcid': '1ddb91d85c72e885',
#   'loc': 'Houston, TX 77046 (Montrose area)',
#   'job_no': 8,
#   'title': 'UX Research Designer',
#   'desc': 'Python, C#, VB.NET, JavaScript, Angular, HTML5, CSS3, AJAX, ASP.NET, REST APIs, Web Services, MVC 4.5, WPF, WebForms, Bootstrap....',
#   'age': '6 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:19'},
#  {'jkid': '40599e00a3811c58',
#   'company': 'ExxonMobil',
#   'jcid': '1ddb91d85c72e885',
#   'loc': 'Spring, TX',
#   'job_no': 9,
#   'title': 'Analytics Innovation Advisor',
#   'desc': 'Analytics, Engineer, Database, SQL, Project Manager, Management, Engineering, Technology. Outstanding skills in various analytical domains including programing...',
#   'age': '7 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:19'},
#  {'jkid': '435f173ad665f5ce',
#   'company': 'ExxonMobil',
#   'jcid': '1ddb91d85c72e885',
#   'loc': 'Houston, TX 77046 (Montrose area)',
#   'job_no': 10,
#   'title': 'Technical Analyst',
#   'desc': 'Relational Database Management Systems & Database Modeling Fundamentals (SQL Server 2012+, Oracle, SQLITE3, MySQL, SQL, PL/SQL, T-SQL)....',
#   'age': '12 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:19'},
#  {'jkid': '4bc00a16420efed4',
#   'company': 'BH Media Group',
#   'jcid': '7601c2041c118c1d',
#   'loc': 'Richmond, VA 23219 (City Center area)',
#   'job_no': 1,
#   'title': 'Applications Analyst',
#   'desc': 'DBMS knowledge including SQL query, database structures, PL/SQL and familiarity. FUNCTION AND SCOPE:....',
#   'age': '13 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:20'},
#  {'jkid': '1e20c7ad80209b17',
#   'company': 'BH Media Group',
#   'jcid': '7601c2041c118c1d',
#   'loc': 'Richmond, VA',
#   'job_no': 2,
#   'title': 'Programmer / Analyst',
#   'desc': 'Working knowledge of Relational DBMS development using PL/SQL (Oracle) or T-SQL (Microsoft SQL Server). 2+ years of software development experience and working...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:20'},
#  {'jkid': 'd7ab9c170fd8e2ce',
#   'company': 'Apple',
#   'jcid': 'c1099851e9794854',
#   'loc': 'Santa Clara Valley, CA',
#   'job_no': 1,
#   'title': 'Cloud DevOps Manager',
#   'desc': 'Perl, python, ruby, go with experience in object oriented programming. Jun 21, 2018....',
#   'age': 'Today',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:21'},
#  {'jkid': '2d99166d3ea0a11e',
#   'company': 'Apple',
#   'jcid': 'c1099851e9794854',
#   'loc': 'Santa Clara Valley, CA',
#   'job_no': 2,
#   'title': 'OS Integration Engineer',
#   'desc': 'Experience with Python and scripting languages (Perl, Ruby, etc.). Jul 6, 2018....',
#   'age': '1 day ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:21'},
#  {'jkid': 'b22aeb5dea9ada9c',
#   'company': 'Apple',
#   'jcid': 'c1099851e9794854',
#   'loc': 'Santa Clara Valley, CA',
#   'job_no': 3,
#   'title': 'Site Reliability Engineer',
#   'desc': 'Summary Posted: Oct 28, 2018 Role Number: 114279108 Imagine what you could do here. At Apple, new ideas have a way of becoming phenomenal products, services,...',
#   'age': '1 day ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:21'},
#  {'jkid': '839f2552b4300df4',
#   'company': 'Apple',
#   'jcid': 'c1099851e9794854',
#   'loc': 'Santa Clara Valley, CA',
#   'job_no': 4,
#   'title': 'iOS Software QA Engineer - Ad Platforms',
#   'desc': 'Superior knowledge of programming in Python and/or JavaScript. Sep 11, 2018....',
#   'age': '1 day ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:21'},
#  {'jkid': '6a227092457595ee',
#   'company': 'Apple',
#   'jcid': 'c1099851e9794854',
#   'loc': 'Santa Clara Valley, CA',
#   'job_no': 5,
#   'title': 'Systems QA Robotics Automation Engineer',
#   'desc': 'Summary Posted: Oct 24, 2018 Weekly Hours: 40 Role Number: 114042031 We are looking for a creative and motivated QA Robotic Automation Engineer with excellent...',
#   'age': '1 day ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:21'},
#  {'jkid': '9929c228e7eab779',
#   'company': 'Apple',
#   'jcid': 'c1099851e9794854',
#   'loc': 'Santa Clara Valley, CA',
#   'job_no': 6,
#   'title': 'US Channel Demand Analyst',
#   'desc': 'Are you adept and have advanced Excel, SQL, along with exposure to statistical methodologies? You are experienced in MySQL, Teradata, SAS, R, Python, Alteryx or...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:21'},
#  {'jkid': '231b7d97b8cf5608',
#   'company': 'Apple',
#   'jcid': 'c1099851e9794854',
#   'loc': 'Santa Clara Valley, CA',
#   'job_no': 7,
#   'title': 'Synthesis - CAD Engineer',
#   'desc': 'Should have experience scripting in TCL or Perl or Python. Oct 27, 2018....',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:21'},
#  {'jkid': '8e6a4342a16fb4d7',
#   'company': 'Apple',
#   'jcid': 'c1099851e9794854',
#   'loc': 'Santa Clara Valley, CA',
#   'job_no': 8,
#   'title': 'Procedural Audio Engineer',
#   'desc': 'Summary Posted: Oct 26, 2018 Role Number: 200004361 Apple’s Technology Development Group is looking for a Procedural Audio Engineer to develop next generation...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:21'},
#  {'jkid': 'bba4b671d9ec62a6',
#   'company': 'Apple',
#   'jcid': 'c1099851e9794854',
#   'loc': 'Santa Clara Valley, CA',
#   'job_no': 9,
#   'title': 'NPI Capacity Program Manager - iPhone',
#   'desc': 'Summary Posted: Oct 26, 2018 Weekly Hours: 40 Role Number: 200003003 Imagine what you could do here. At Apple, new ideas have a way of becoming extraordinary...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:21'},
#  {'jkid': '43891c3c48d5d611',
#   'company': 'Apple',
#   'jcid': 'c1099851e9794854',
#   'loc': 'Santa Clara Valley, CA',
#   'job_no': 10,
#   'title': 'Motion Sensing Hardware Engineer: Pressure Sensors',
#   'desc': 'Summary Posted: Oct 26, 2018 Role Number: 200003980 You will play a key role in specifying, developing, characterizing, and validating motion sensing systems....',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:21'},
#  {'jkid': '2bcccbc71191d9dc',
#   'company': 'UnitedHealth Group',
#   'jcid': 'd3d3520998346837',
#   'loc': 'Minnetonka, MN 55345',
#   'job_no': 1,
#   'title': 'Senior Java Engineer',
#   'desc': '2+ years SQL database experience. Good understanding of ETL and Reporting Tool integration. At Optum, you can bring your passion for innovation to an Agile...',
#   'age': 'Today',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:22'},
#  {'jkid': '35a0af724a37f66e',
#   'company': 'UnitedHealth Group',
#   'jcid': 'd3d3520998346837',
#   'loc': 'Tampa, FL 33646 (Downtown area)',
#   'job_no': 2,
#   'title': 'Business System Analyst',
#   'desc': '1+ year of experience writing SQL queries to retrieve data, analyze/store data for research, reference, future use and using SQL Server Management Studio....',
#   'age': '1 day ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:22'},
#  {'jkid': '01d678d4c83fc701',
#   'company': 'UnitedHealth Group',
#   'jcid': 'd3d3520998346837',
#   'loc': 'Eden Prairie, MN 55344',
#   'job_no': 3,
#   'title': 'SR. MDM Configurator/Architect',
#   'desc': 'Experience with relational databases DB2, Oracle, SQL Server or others; In this role as a MDM Lead Developer/Architect you will be responsible for working with...',
#   'age': '1 day ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:22'},
#  {'jkid': 'a8cbba37e91124a6',
#   'company': 'UnitedHealth Group',
#   'jcid': 'd3d3520998346837',
#   'loc': 'Orlando, FL 32885 (Central Business District area)',
#   'job_no': 4,
#   'title': 'Business Analysis Consultant//Tableau Developer',
#   'desc': 'Tough challenges? We know a thing or two about those. When you’re on a mission to help people live healthier lives, the stakes couldn’t be higher. As a...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:22'},
#  {'jkid': '4e06c13c6033710f',
#   'company': 'UnitedHealth Group',
#   'jcid': 'd3d3520998346837',
#   'loc': 'Eden Prairie, MN 55344',
#   'job_no': 5,
#   'title': 'Financial Analyst',
#   'desc': "Demonstrate understanding and proficiency of relevant tools (Excel, SAS, SQL). Aspiring to help people live healthier lives isn't just a goal we're after?it's...",
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:22'},
#  {'jkid': '08e441598af81ef0',
#   'company': 'UnitedHealth Group',
#   'jcid': 'd3d3520998346837',
#   'loc': 'Eden Prairie, MN 55344',
#   'job_no': 6,
#   'title': 'Senior Reporting Analyst',
#   'desc': "Experience Alteryx or SSIS or any other ETL tool. We'll put you in the driver's seat on vital projects that have strategic importance to our mission of helping...",
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:22'},
#  {'jkid': 'da45586f134fd23a',
#   'company': 'UnitedHealth Group',
#   'jcid': 'd3d3520998346837',
#   'loc': 'Phoenix, AZ 85003 (Central City area)',
#   'job_no': 7,
#   'title': 'Software Engineer',
#   'desc': 'ETL Tool like Data Stage 8.7 (or higher) or Talend. The health solutions marketplace is hungry for new ideas, innovative products and software that drives...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:22'},
#  {'jkid': 'ebf1eece40ada500',
#   'company': 'UnitedHealth Group',
#   'jcid': 'd3d3520998346837',
#   'loc': 'Minnetonka, MN 55345',
#   'job_no': 8,
#   'title': 'Financial Consultant',
#   'desc': 'Working knowledge of Access, SQL or SAS. Operate, maintain and redesign complex financial models in Microsoft Access, Excel and SQL....',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:22'},
#  {'jkid': 'd0a258dad6f7c257',
#   'company': 'UnitedHealth Group',
#   'jcid': 'd3d3520998346837',
#   'loc': 'Minnetonka, MN 55345',
#   'job_no': 9,
#   'title': 'Software Developer',
#   'desc': '3+ years of knowledge and use of the ETL tools - SQL Server Integration Services (SSIS). 3+ years of SQL coding experience....',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:22'},
#  {'jkid': 'eac6e3d61e6d039e',
#   'company': 'UnitedHealth Group',
#   'jcid': 'd3d3520998346837',
#   'loc': 'Irvine, CA',
#   'job_no': 10,
#   'title': 'Business Analyst Consultant',
#   'desc': 'Microsoft SQL Server, SSIS, SSMS, stored procedures; The Business Analyst Consultant will support the Formulary Operations team in developing, enhancing, and...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:22'},
#  {'jkid': '08142335e4ccf534',
#   'company': 'McKesson',
#   'jcid': 'a7c5036618407010',
#   'loc': 'Scottsdale, AZ 85262',
#   'job_no': 1,
#   'title': 'Busi Intelligence Analyst',
#   'desc': 'Knowledge of data tools, such as SQL, NoSQL, Visual Basic, SAP, IBM, Neteeza, Teradata, Hadoop, and Oracle. McKesson is in the business of better health and we...',
#   'age': 'Today',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:23'},
#  {'jkid': 'a2fb131a5b19e6ff',
#   'company': 'McKesson',
#   'jcid': 'a7c5036618407010',
#   'loc': 'San Francisco, CA 94104 (Financial District area)',
#   'job_no': 2,
#   'title': 'Software Developer 3 (McKesson Specialty Health)',
#   'desc': 'Develop full stack application business logic using GWT, Java, J2EE, SQL, html, CSS, xml, and other related technologies....',
#   'age': 'Today',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:23'},
#  {'jkid': '12b9626dd7e713f1',
#   'company': 'McKesson',
#   'jcid': 'a7c5036618407010',
#   'loc': 'Atlanta, GA 30329',
#   'job_no': 3,
#   'title': 'Software Engineer, ASP.NET, C#, HTML, JSON, XML',
#   'desc': '4+ years of SQL Server 2014/2017. Experience with SQL Server Integrated Services (SSIS). Experience with performance tuning and analysis in Microsoft SQL Server...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:23'},
#  {'jkid': '8c451f16206c824b',
#   'company': 'McKesson',
#   'jcid': 'a7c5036618407010',
#   'loc': 'Irving, TX',
#   'job_no': 4,
#   'title': 'Intelligent Automation Analyst',
#   'desc': 'Proficient with programming languages Python and R. McKesson is in the business of better health and we touch the lives of patients in virtually every aspect of...',
#   'age': '4 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:23'},
#  {'jkid': '6571575e0a86b6ec',
#   'company': 'McKesson',
#   'jcid': 'a7c5036618407010',
#   'loc': 'New Albany, OH',
#   'job_no': 5,
#   'title': 'Senior Software Developer',
#   'desc': 'McKesson is in the business of better health and we touch the lives of patients in virtually every aspect of healthcare. We partner with payors, hospitals,...',
#   'age': '4 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:23'},
#  {'jkid': '63e1ce2690c3098d',
#   'company': 'McKesson',
#   'jcid': 'a7c5036618407010',
#   'loc': 'Richmond, VA',
#   'job_no': 6,
#   'title': 'Associate e-Commerce Pricing Analyst',
#   'desc': 'SQL. R, Python, Tableau, Oracle, and Power BI. Utilize SQL, Excel, and data visualization tools to aid in performance quantitative and qualitative analysis,...',
#   'age': '5 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:23'},
#  {'jkid': 'e629a65befcd2cf3',
#   'company': 'McKesson',
#   'jcid': 'a7c5036618407010',
#   'loc': 'Irving, TX',
#   'job_no': 7,
#   'title': 'Business Intelligence Technical Lead',
#   'desc': 'Familiarity with SQL Server and SQL Server Integration Services (SSIS). Proficiency with Python and/or R for both data analysis and automation....',
#   'age': '5 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:23'},
#  {'jkid': '9a7d41ca35e81d1a',
#   'company': 'McKesson',
#   'jcid': 'a7c5036618407010',
#   'loc': 'Atlanta, GA 30329',
#   'job_no': 8,
#   'title': 'Software Engineer, .Net or C# or JAVA, Shell Scripting, SQL',
#   'desc': 'PowerShell or Shell Scripting and SQL. A minimum of 5 years of SQL Server/Oracle required. RelayHealth Pharmacy Solutions (RHPS), a McKesson connectivity...',
#   'age': '6 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:23'},
#  {'jkid': '0dedfac7ab278ef3',
#   'company': 'McKesson',
#   'jcid': 'a7c5036618407010',
#   'loc': 'Atlanta, GA 30329',
#   'job_no': 9,
#   'title': 'Product Innovation Manager',
#   'desc': 'Basic understanding of SQL. McKesson is in the business of better health and we touch the lives of patients in virtually every aspect of healthcare....',
#   'age': '7 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:23'},
#  {'jkid': '947b97f93608f079',
#   'company': 'McKesson',
#   'jcid': 'a7c5036618407010',
#   'loc': 'Richmond, VA',
#   'job_no': 10,
#   'title': 'Operations Data Analyst',
#   'desc': '6+ months experience with SQL, data extraction methodologies, relational and dimensional databases methods. McKesson is in the business of better health and we...',
#   'age': '11 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:23'},
#  {'jkid': 'dd9e761c1f2ac8eb',
#   'company': 'CVS Health',
#   'jcid': '1419e52fd7c725ce',
#   'loc': 'Cumberland, OH',
#   'job_no': 1,
#   'title': 'Enterprise Disaster Recovery, System Integration Analyst',
#   'desc': 'Knowledge of AIX, SOLARIS, MICROSOFT, MAINFRAME, and AS400 technologies including db2, SQL, Oracle, MariaDB, (IIS), file systems, LDAP, AD, Network, MQ, VMWare,...',
#   'age': 'Today',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:24'},
#  {'jkid': 'e7ee439f40e90447',
#   'company': 'CVS Health',
#   'jcid': '1419e52fd7c725ce',
#   'loc': 'Woonsocket, RI',
#   'job_no': 2,
#   'title': 'Analytics, Supply Chain/Inventory Analytics Advisor',
#   'desc': 'Minimum of two years processing large data-sets (measured in hundreds of millions or billions of records) using data mining programs such as SQL....',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:24'},
#  {'jkid': 'b28d1fbbbb755d21',
#   'company': 'CVS Health',
#   'jcid': '1419e52fd7c725ce',
#   'loc': 'Greensboro, NC 27410',
#   'job_no': 3,
#   'title': '.NET Application Development - Advisor',
#   'desc': 'SQL Server 2008 and above. The .NET Application Development Advisor is primarily responsible for designing and developing solutions to meet the customer’s...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:24'},
#  {'jkid': '10b65bc75cf99d3e',
#   'company': 'CVS Health',
#   'jcid': '1419e52fd7c725ce',
#   'loc': 'Northbrook, IL',
#   'job_no': 4,
#   'title': 'Healthcare Analyst',
#   'desc': 'Knowledge of SAS and SQL or other statistical and database software, including STATA, SPSS, and R. As a Healthcare Analyst, you will be developing and/or...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:24'},
#  {'jkid': '5fa03fb4b616e5ac',
#   'company': 'CVS Health',
#   'jcid': '1419e52fd7c725ce',
#   'loc': 'Northbrook, IL',
#   'job_no': 5,
#   'title': 'Undergrad Intern - Analytic Consulting Services',
#   'desc': 'CVS Health offers a comprehensive internship program designed to engage students, impart valuable skills, and offer insight into a potential career path with...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:24'},
#  {'jkid': '3102f1d3ad949543',
#   'company': 'CVS Health',
#   'jcid': '1419e52fd7c725ce',
#   'loc': 'Illinois',
#   'job_no': 6,
#   'title': 'Manager of Finance',
#   'desc': 'Experience with Teradata and Oracle SQL environments and Tableau. CVS Caremark and Minute Clinic have established a variety of programs and offerings to support...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:24'},
#  {'jkid': 'd94ad88cebefcaaa',
#   'company': 'CVS Health',
#   'jcid': '1419e52fd7c725ce',
#   'loc': 'Richardson, TX',
#   'job_no': 7,
#   'title': 'Quality Assurance - Advisor',
#   'desc': 'Utilize SQL queries to generate Ad-hoc reports. The Quality Assurance Advisor is a member of the Digital Quality Assurance team responsible for delivering...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:24'},
#  {'jkid': '6615fab4264cdf2e',
#   'company': 'CVS Health',
#   'jcid': '1419e52fd7c725ce',
#   'loc': 'Smithfield, RI',
#   'job_no': 8,
#   'title': 'Data Warehouse / Oracle Developer, Advisor',
#   'desc': 'Hands-on experience and knowledge of Data Warehouse best practices, Oracle, SQL, PL/SQL, Unix/Linux and working knowledge of SDLC/agile methodology is required...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:24'},
#  {'jkid': 'a34c6142ce882e46',
#   'company': 'CVS Health',
#   'jcid': '1419e52fd7c725ce',
#   'loc': 'Scottsdale, AZ',
#   'job_no': 9,
#   'title': 'Medicare Operations Med D Manager',
#   'desc': 'Advanced technical skills with knowledge of SQL, SAS, TeraData Microsoft Excel and Access. Candidates must possess the ability to work well in a...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:24'},
#  {'jkid': '16d97e297baa4371',
#   'company': 'CVS Health',
#   'jcid': '1419e52fd7c725ce',
#   'loc': 'Northbrook, IL',
#   'job_no': 10,
#   'title': 'Senior Healthcare Analyst',
#   'desc': 'Knowledge of SAS or other statistical and database software, including STATA, SPSS, R, and SQL highly preferred....',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:24'},
#  {'jkid': '5b01eb7cc587cb72',
#   'company': 'Amazon.com',
#   'jcid': 'fe2d21eef233e94a',
#   'loc': 'United States',
#   'job_no': 1,
#   'title': 'Alexa VUI Architect',
#   'desc': 'Experience with modern programming languages (Java, JavaScript, C/C++, Objective C, Python, Ruby). Are you passionate about the intersection of cloud computing,...',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:25'},
#  {'jkid': '1a4561b2eb3aef3a',
#   'company': 'Amazon.com',
#   'jcid': 'fe2d21eef233e94a',
#   'loc': 'Seattle, WA',
#   'job_no': 2,
#   'title': 'Business Insights Analyst',
#   'desc': 'SQL skills and experience in joining/cleansing datasets from multiple sources. Amazon Web Services (AWS) provides companies of all sizes with an infrastructure...',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:25'},
#  {'jkid': 'bc3a675b62d52054',
#   'company': 'Amazon.com',
#   'jcid': 'fe2d21eef233e94a',
#   'loc': 'Seattle, WA',
#   'job_no': 3,
#   'title': 'Intern - Economics',
#   'desc': 'Experience with SQL. Some knowledge of econometrics, as well as basic familiarity with Stata or R is necessary, and experience with SQL would be a plus....',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:25'},
#  {'jkid': '191a785ee671602e',
#   'company': 'Amazon.com',
#   'jcid': 'fe2d21eef233e94a',
#   'loc': 'Seattle, WA',
#   'job_no': 4,
#   'title': 'Alexa Shopping Business Intelligence Engineer',
#   'desc': 'Excellent knowledge and Expertise with SQL, Linux, OLAP, and Relational, NoSQL & Multi-dimensional Databases, Big Data....',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:25'},
#  {'jkid': 'a5ba1c1cc57d6a58',
#   'company': 'Amazon.com',
#   'jcid': 'fe2d21eef233e94a',
#   'loc': 'Seattle, WA',
#   'job_no': 5,
#   'title': 'Quality Assurance Engineer | Amazon Exports and Expansion',
#   'desc': 'Experience with user-level automation frameworks and scripting via Perl, Python, or JavaScript. The Amazon Exports and Expansion technology team is looking for...',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:25'},
#  {'jkid': '7ba75c4029b1c796',
#   'company': 'Amazon.com',
#   'jcid': 'fe2d21eef233e94a',
#   'loc': 'Seattle, WA',
#   'job_no': 6,
#   'title': 'Manufacturing Test Engineer',
#   'desc': 'Experience in C, C++, python or Java programming. Experience in Java and Python programming in a GNU/Linux development environment....',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:25'},
#  {'jkid': '2552fa730d0e516a',
#   'company': 'Amazon.com',
#   'jcid': 'fe2d21eef233e94a',
#   'loc': 'Seattle, WA',
#   'job_no': 7,
#   'title': 'Senior Financial Analyst',
#   'desc': 'Job Description Amazon seeks a Sr. Financial Analyst to play a key role on the Digital, App, and Game Services (DAGS) finance team. The DAGS organization...',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:25'},
#  {'jkid': '9b7d9471b968fd39',
#   'company': 'Amazon.com',
#   'jcid': 'fe2d21eef233e94a',
#   'loc': 'Herndon, VA',
#   'job_no': 8,
#   'title': 'Cloud Support Associate - Databases',
#   'desc': 'The position offers the chance to learn and master a wide variety of database engines, from commercial engines (Oracle and SQL Server) to open source engines...',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:25'},
#  {'jkid': '1a93738d61eb2ba4',
#   'company': 'Amazon.com',
#   'jcid': 'fe2d21eef233e94a',
#   'loc': 'Seattle, WA',
#   'job_no': 9,
#   'title': 'Instock Manager - Packaged Deli',
#   'desc': 'Experience with SQL. We are looking for an Instock Manager to support the Packaged Deli category....',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:25'},
#  {'jkid': '3c2b78e7c3f8098b',
#   'company': 'Amazon.com',
#   'jcid': 'fe2d21eef233e94a',
#   'loc': 'Seattle, WA',
#   'job_no': 10,
#   'title': 'Research Scientist - Prime Air',
#   'desc': 'Proficiency in Python or MATLAB. Proficiency in C/C++ and Python or MATLAB. We’re working on the future....',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:25'},
#  {'jkid': 'a5d1d583b9ecf52d',
#   'company': 'AT&T',
#   'jcid': '25b5166547bbf543',
#   'loc': 'Dallas, GA 30132',
#   'job_no': 1,
#   'title': 'Advanced Analytics',
#   'desc': 'Developing hypotheses and methodology for the analysis, preforming the analysis using SQL or SAS, summarizing their findings and recommendations in a persuasive...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:26'},
#  {'jkid': '9ed58e13e621bcb4',
#   'company': 'AT&T',
#   'jcid': '25b5166547bbf543',
#   'loc': 'Middletown, NJ',
#   'job_no': 2,
#   'title': 'Principal-Technology Security',
#   'desc': 'Python, Go, Perl Scripting experience a plus. Review and analysis of security requirements, works with senior team....',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:26'},
#  {'jkid': 'd2f09b68a742788e',
#   'company': 'AT&T',
#   'jcid': '25b5166547bbf543',
#   'loc': 'Piscataway, NJ',
#   'job_no': 3,
#   'title': 'Senior-Software Engineer (DevSecOps)',
#   'desc': 'Experience working with SQL and noSQL data stores and Hibernate or other ORM technologies. Microsoft technologies, MicroSoft SQL, Visual BAsic, MS Access VBA,...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:26'},
#  {'jkid': 'daf7a406d5eafea3',
#   'company': 'AT&T',
#   'jcid': '25b5166547bbf543',
#   'loc': 'Oakton, VA',
#   'job_no': 4,
#   'title': 'Database Administrator (Westfields)',
#   'desc': 'Oracle, PostgreSQL, MySQL, Microsoft SQL Server, and, HADOOP. Responsible for database design, implementation, and maintenance, and the operation and setup of...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:26'},
#  {'jkid': 'f1b607b35cbbd632',
#   'company': 'AT&T',
#   'jcid': '25b5166547bbf543',
#   'loc': 'Oakton, VA',
#   'job_no': 5,
#   'title': 'IS Security Analyst (Westfields)',
#   'desc': 'Desired:CND experience, Department of Defense experience, *NIX familiarity, Command Line Scripting skills (PERL, Python, PowerShell scripting) to automate...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:26'},
#  {'jkid': 'ca95457051aedadd',
#   'company': 'AT&T',
#   'jcid': '25b5166547bbf543',
#   'loc': 'Oakton, VA',
#   'job_no': 6,
#   'title': 'Network Management System Designer (Westfields)',
#   'desc': 'SQL query development a plus. Intermediate or higher knowledge of Python. Ensure cleanliness and optimization of code written in complied languages such as Java...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:26'},
#  {'jkid': '875d10dd909c118f',
#   'company': 'AT&T',
#   'jcid': '25b5166547bbf543',
#   'loc': 'St. Louis, MO',
#   'job_no': 7,
#   'title': 'Senior-Database Administration',
#   'desc': 'The operational database support responsibilities include those related to availability, performance, currency, integrity, security, and confidentiality of the...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:26'},
#  {'jkid': 'bb34757764cb5f6a',
#   'company': 'AT&T',
#   'jcid': '25b5166547bbf543',
#   'loc': 'Ogden, UT',
#   'job_no': 8,
#   'title': 'Network Controller/Operator Lead (Government)',
#   'desc': 'BASH, Perl, Python Scripting experience. AT&T is seeking hard-working and dependable candidates to support of the GSM-O contract at Defense Information Systems...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:26'},
#  {'jkid': '0bf0d32fc05a46de',
#   'company': 'AT&T',
#   'jcid': '25b5166547bbf543',
#   'loc': 'Collinsville, IL',
#   'job_no': 9,
#   'title': 'Information Systems Security Specialist Associate (Governmen...',
#   'desc': 'Desired Experience, Education, and Certifications CND experience Department of Defense experience *NIX familiarity Command Line Scripting skills (PERL, Python,...',
#   'age': '5 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:26'},
#  {'jkid': '49a79a9b4ec1d950',
#   'company': 'AT&T',
#   'jcid': '25b5166547bbf543',
#   'loc': 'Collinsville, IL',
#   'job_no': 10,
#   'title': 'Senior Computer Security Systems Specialist-Lead (Government...',
#   'desc': 'Desired Experience, Education, and Certifications CND experience Department of Defense experience *NIX familiarity Command Line Scripting skills (PERL, Python,...',
#   'age': '5 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:26'},
#  {'jkid': '471641f88885668b',
#   'company': 'Smithfield Foods',
#   'jcid': '47a15cde3c2472ae',
#   'loc': 'Kansas City, MO',
#   'job_no': 1,
#   'title': 'Enterprise Solutions Architect',
#   'desc': 'The Enterprise Solutions Architect creates deliverables that help develop a direction for managing the organization\'s portfolio of "to be" and "as is...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:27'},
#  {'jkid': 'bf9d34df1b509b38',
#   'company': 'Smithfield Foods',
#   'jcid': '47a15cde3c2472ae',
#   'loc': 'Kansas City, MO',
#   'job_no': 2,
#   'title': 'Applications Development Manager-Plant Systems',
#   'desc': 'This role will be critical with any system implementations involving application deployments to ensure IT and its third party strategic service providers or...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:27'},
#  {'jkid': '200bb98c7cad2bda',
#   'company': 'Henry Ford Health System',
#   'jcid': 'fcee73a6346b7a5b',
#   'loc': 'Detroit, MI',
#   'job_no': 1,
#   'title': 'Student',
#   'desc': 'Basic to intermediate SQL knowledge or experience highly preferred. Assist with month-end performance reports....',
#   'age': '28 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': '587ecd734e27870d',
#   'company': 'Henry Ford Health System',
#   'jcid': 'fcee73a6346b7a5b',
#   'loc': 'Detroit, MI',
#   'job_no': 2,
#   'title': 'Manager',
#   'desc': 'Reporting to the Director, Revenue Integrity, the Manager, Revenue Reporting & Analytics, is responsible for improving revenue results by taking a global view...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': 'a72b387d0497afd0',
#   'company': 'Henry Ford Health System',
#   'jcid': 'fcee73a6346b7a5b',
#   'loc': 'Detroit, MI',
#   'job_no': 3,
#   'title': 'IT Manager',
#   'desc': 'B) Windows and Unix scripting, SQL , PL/SQL. A) ETL tools like Microsoft SSIS/ Data stage / Informatica / AbInitio....',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': 'fdb598831b570b37',
#   'company': 'Henry Ford Health System',
#   'jcid': 'fcee73a6346b7a5b',
#   'loc': 'Troy, MI',
#   'job_no': 4,
#   'title': 'Principal Performance Measurement Analyst',
#   'desc': 'Under direction of a Manager or a Director, develops and implements a comprehensive program to collect data and effectively report information from these data...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': '9d645dbf9162896a',
#   'company': 'Henry Ford Health System',
#   'jcid': 'fcee73a6346b7a5b',
#   'loc': 'Detroit, MI',
#   'job_no': 5,
#   'title': 'Data Analytics Programmer – Provider Affairs',
#   'desc': 'Must be proficient in SQL Server, Open Source, NoSQL databases including HBase, MongoDB. This individual’s work will mobilize the data from SQL query into...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': '8e99d5dd93034b16',
#   'company': 'Henry Ford Community College',
#   'jcid': '0be6857c016377e9',
#   'loc': 'Dearborn, MI',
#   'job_no': 6,
#   'title': 'Applications Systems Analyst',
#   'desc': 'MS SQL Server 2005/2008/2012. Query and reporting tools including SQL, IBI WebFocus, Crystal Reports and Business Objects or similar reporting tools....',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': '975f697e64c0f5fc',
#   'company': 'AmerisourceBergen',
#   'jcid': 'a6362e26eb1427c7',
#   'loc': 'Frisco, TX',
#   'job_no': 1,
#   'title': 'Technical Business Analyst - Web',
#   'desc': 'Demonstrates excellent knowledge of SQL and SQL queries. Are you looking to make a difference in a patient’s life?...',
#   'age': '4 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': '284d11dd10a95673',
#   'company': 'AmerisourceBergen',
#   'jcid': 'a6362e26eb1427c7',
#   'loc': 'Chesterbrook, PA',
#   'job_no': 2,
#   'title': 'Applied Analytics & Commercial Process Analyst',
#   'desc': 'Familiarity with data visualization and statistical analysis tools (PowerBI, Tableau, Qlik, SQL, R, Python). Are you looking to make a difference in a patient’s...',
#   'age': '9 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': '48332f273f73a3f0',
#   'company': 'AmerisourceBergen',
#   'jcid': 'a6362e26eb1427c7',
#   'loc': 'Frisco, TX',
#   'job_no': 3,
#   'title': 'Test Engineer II',
#   'desc': '2+ years of SQL querying experience to help with testing. Are you looking to make a difference in a patient’s life?...',
#   'age': '11 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': 'dc09a110fbdfa779',
#   'company': 'AmerisourceBergen',
#   'jcid': 'a6362e26eb1427c7',
#   'loc': 'Lake Forest, IL',
#   'job_no': 4,
#   'title': 'SQL Database Administrator',
#   'desc': 'Experience with SQL Server 2012 and newer. Troubleshoots and resolves applications (ex., SQL) performance issues....',
#   'age': '26 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': '8bea726cd3a69fc2',
#   'company': 'AmerisourceBergen',
#   'jcid': 'a6362e26eb1427c7',
#   'loc': 'Amarillo, TX',
#   'job_no': 5,
#   'title': 'Lead Data Engineer',
#   'desc': '8 or more years of experience in technologies relevant to data/information management, such as SQL, RDBMS, Data Lake/Hadoop, MDM, Metadata, Data Quality, etc....',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': '83734b922b6bbdf6',
#   'company': 'AmerisourceBergen',
#   'jcid': 'a6362e26eb1427c7',
#   'loc': 'Amarillo, TX',
#   'job_no': 6,
#   'title': 'Data Visualization Specialist III',
#   'desc': '5-10 Years of experience with data visualization/BI tools, such as Qlik or Tableau, SQL and semantic data access mechanisms....',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': 'e2ddfed2545aa939',
#   'company': 'AmerisourceBergen',
#   'jcid': 'a6362e26eb1427c7',
#   'loc': 'Chesterbrook, PA',
#   'job_no': 7,
#   'title': 'Data Engineer, MDM',
#   'desc': '5-10 years of experience in technologies relevant to data/information management, such as SQL, MDM, Metadata, Data Quality, etc....',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': '61b95afd3ee5de17',
#   'company': 'AmerisourceBergen',
#   'jcid': 'a6362e26eb1427c7',
#   'loc': 'Frisco, TX',
#   'job_no': 8,
#   'title': 'SQL Developer',
#   'desc': 'SQL Server 2005 and SQL Server 2008 (SQL Server 2012 a plus). SQL Server Database Architecture and Design (OLTP/OLAP) and SQL Server Database Programming and...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': 'ac2adab4db0852ad',
#   'company': 'AmerisourceBergen',
#   'jcid': 'a6362e26eb1427c7',
#   'loc': 'Fort Mill, SC',
#   'job_no': 9,
#   'title': 'Director , Data Management & Operations',
#   'desc': 'Define data architecture, infrastructure, and engineering standards, processes and policies to be applied to building scalable and highly available data...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': 'a2fe6e25b5f5d6fb',
#   'company': 'AmerisourceBergen',
#   'jcid': 'a6362e26eb1427c7',
#   'loc': 'Amarillo, TX',
#   'job_no': 10,
#   'title': 'Quality Assurance Analyst',
#   'desc': 'Basic knowledge of databases and database query language, such as SQL, recommended. Uses various tools effectively to assist in project completion, including...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:28'},
#  {'jkid': '78ca4ac7040cbe69',
#   'company': 'Cardinal Health',
#   'jcid': '87b328666e50453b',
#   'loc': 'Dublin, OH 43017',
#   'job_no': 1,
#   'title': 'Strategic Pricing',
#   'desc': 'Data management / manipulation skills – SQL / Data mining / or Advanced Excel required. What Strategic Pricing contributes to Cardinal Health....',
#   'age': 'Just posted',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:31'},
#  {'jkid': 'cc390483010713c0',
#   'company': 'Cardinal Health',
#   'jcid': '87b328666e50453b',
#   'loc': 'Dublin, OH 43017',
#   'job_no': 2,
#   'title': 'Senior Consultant, Advanced Analytics',
#   'desc': 'Familiarity with statistical computer languages (R, Python). Familiarity with data querying and merging tools such as SQL or Business Objects....',
#   'age': 'Today',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:31'},
#  {'jkid': 'dd083a21f97f8a7a',
#   'company': 'Cardinal Health',
#   'jcid': '87b328666e50453b',
#   'loc': 'Dublin, OH 43017',
#   'job_no': 3,
#   'title': 'Pricing Strategic Analytics',
#   'desc': 'Strong SQL & Data Engineering Skills Ability to “Tell the Story” and drive towards solutions for complex business problems....',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:31'},
#  {'jkid': '40c0458e629fdfa3',
#   'company': 'Cardinal Health',
#   'jcid': '87b328666e50453b',
#   'loc': 'Twinsburg, OH 44087',
#   'job_no': 4,
#   'title': 'Engineer, Software Engineering (EDI Developer)',
#   'desc': 'SQL experience is desired and the ability to coding and script within SQL and VB. Working together, we can make a difference in healthcare for our customers and...',
#   'age': '4 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:31'},
#  {'jkid': 'ae0730566e119706',
#   'company': 'Cardinal Health',
#   'jcid': '87b328666e50453b',
#   'loc': 'Dublin, OH 43017',
#   'job_no': 5,
#   'title': 'Engineer, Software Engineering (Manhattan WMS) (P-Mod)',
#   'desc': 'Experience with SQL scripting for test executions would be a plus. Working together, we can make a difference in healthcare for our customers and communities....',
#   'age': '5 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:31'},
#  {'jkid': '0669ab7917285eba',
#   'company': 'Cardinal Health',
#   'jcid': '87b328666e50453b',
#   'loc': 'Guaynabo, PR 00965',
#   'job_no': 6,
#   'title': 'Sr. Specialist Product Support - Pyxis',
#   'desc': 'Knowledge in SQL and computer equipment configuration is preferred. What Product Support/Repair - Field and Depot contributes to Cardinal Health....',
#   'age': '12 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:31'},
#  {'jkid': 'f2cd32a387dd3ad8',
#   'company': 'Cardinal Health',
#   'jcid': '87b328666e50453b',
#   'loc': 'Dublin, OH 43017',
#   'job_no': 7,
#   'title': 'Consultant, Business Intelligence',
#   'desc': 'Experience with SQL or other database languages preferred. What Business Intelligence contributes to Cardinal Health....',
#   'age': '12 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:31'},
#  {'jkid': '64b4a98c5e15deb7',
#   'company': 'Cardinal Health',
#   'jcid': '87b328666e50453b',
#   'loc': 'Westlake Village, CA 91362',
#   'job_no': 8,
#   'title': 'Senior Analyst - FP&A',
#   'desc': 'Extract and manipulate financial data using SQL and Excel. What Financial Planning & Analysis contributes to Cardinal Health....',
#   'age': '7 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:31'},
#  {'jkid': '1dfca1fe05b30edb',
#   'company': 'Cardinal Health',
#   'jcid': '87b328666e50453b',
#   'loc': 'Concord, MA 01742',
#   'job_no': 9,
#   'title': 'CIMS Customer and Field Operations Support Manager',
#   'desc': 'Basic understanding of Linux and SQL preferred. Cardinal Health Inventory Management Solutions (CIMS) is a SaaS solution enabling healthcare providers and...',
#   'age': '20 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:31'},
#  {'jkid': '507cb905f3873cd9',
#   'company': 'Cardinal Health',
#   'jcid': '87b328666e50453b',
#   'loc': 'Dublin, OH 43017',
#   'job_no': 10,
#   'title': 'Consultant, Advanced Analytics, OptiFreight Logistics',
#   'desc': 'Certification/proficiency in SQL Server Reporting Services, Tableau, and various other reporting visualization tools....',
#   'age': '27 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:31'},
#  {'jkid': '3b5c4dad65e47382',
#   'company': 'Costco Wholesale',
#   'jcid': '9b77e2b0ccfb3838',
#   'loc': 'Issaquah, WA 98027',
#   'job_no': 1,
#   'title': 'SAP Basis HANA Administrator #1998~',
#   'desc': 'Technically fluent in SQL. Costco Wholesale is currently seeking an SAP HANA Basis Administrator experienced in establishing and carrying out implementations of...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:32'},
#  {'jkid': 'e94ed547ed3d6bf1',
#   'company': 'Costco Wholesale',
#   'jcid': '9b77e2b0ccfb3838',
#   'loc': 'Issaquah, WA 98027',
#   'job_no': 2,
#   'title': 'Advanced Analytics Analyst #2680~',
#   'desc': 'Experience using R and/or Python. If you are excited about harnessing “Artificial Intelligence” to solve business problems, then read on....',
#   'age': '5 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:32'},
#  {'jkid': 'e9f68647c4ebc98b',
#   'company': 'Costco Wholesale',
#   'jcid': '9b77e2b0ccfb3838',
#   'loc': 'Issaquah, WA 98027',
#   'job_no': 3,
#   'title': 'Technical Services Coordinator~',
#   'desc': '2+ years’ building relational databases using MYSQL and/or SQL. Strong knowledge of SQL language and ability to write complex statements....',
#   'age': '10 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:48:32'},
#  {'jkid': '05e5368ef7d5c7d3',
#   'company': 'Costco Wholesale',
#   'jcid': '9b77e2b0ccfb3838',
#   'loc': 'Issaquah, WA 98027',
#   'job_no': 4,
#   'title': 'Kronos WFC Developer #2507~',
# ...
#   'loc': 'New Brunswick, NJ 08903',
#   'job_no': 5,
#   'title': 'Director of Quality Analytics',
#   'desc': 'SAP HANA, SQL, Oracle. The GPS (Global Product Development and Supply) Analytics team is a newly formed and growing team within Business Insights and Analytics...',
#   'age': '5 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:10'},
#  {'jkid': 'b82f8d0e86426757',
#   'company': 'Bristol-Myers Squibb',
#   'jcid': '45f7e11d0973ee3a',
#   'loc': 'New Brunswick, NJ 08903',
#   'job_no': 6,
#   'title': 'Director of Manufacturing Operations Analytics',
#   'desc': 'SAP HANA, SQL, Oracle. The GPS (Global Product Development and Supply) Analytics team is a newly formed and growing team within Business Insights and Analytics...',
#   'age': '6 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:10'},
#  {'jkid': 'e152ca33d97bb5e2',
#   'company': 'Bristol-Myers Squibb',
#   'jcid': '45f7e11d0973ee3a',
#   'loc': 'Tampa, FL 33602 (Downtown area)',
#   'job_no': 7,
#   'title': 'Systems Development, Integration & Operations, Enterprise Da...',
#   'desc': 'Digital Capability Management, Data Engineering, Enterprise Data Lake and Integration Technical delivery of BMS’s Enterprise Data Lake solutions in IDM across...',
#   'age': '6 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:10'},
#  {'jkid': '1be0972b9987e745',
#   'company': 'Bristol-Myers Squibb',
#   'jcid': '45f7e11d0973ee3a',
#   'loc': 'New Brunswick, NJ 08903',
#   'job_no': 8,
#   'title': 'Data Architecture, GPS',
#   'desc': 'Key Responsibilities: Accountable for driving information and data architecture decisions for GPS (Global Product Development & Supply) digital capabilities...',
#   'age': '11 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:10'},
#  {'jkid': '17ad8c75a532f9c5',
#   'company': 'Bristol-Myers Squibb',
#   'jcid': '45f7e11d0973ee3a',
#   'loc': 'New Brunswick, NJ 08903',
#   'job_no': 9,
#   'title': 'Data Architecture, R&D',
#   'desc': 'Key Responsibilities: Accountable for driving information and data architecture decisions for R&D; digital capabilities in alignment with enterprise...',
#   'age': '11 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:10'},
#  {'jkid': '8561e999d9e223e4',
#   'company': 'Bristol-Myers Squibb',
#   'jcid': '45f7e11d0973ee3a',
#   'loc': 'Devens, MA 01434',
#   'job_no': 10,
#   'title': 'Associate Data Engineer',
#   'desc': 'Assist in building and maintaining data warehouse data integrations leveraging both MS SQL Integration services and Python technologies....',
#   'age': '10 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:10'},
#  {'jkid': '0943c2877e95df6e',
#   'company': 'Halliburton',
#   'jcid': '0e4554ac6dcff427',
#   'loc': 'Houston, TX 77032',
#   'job_no': 1,
#   'title': 'Consultant, Sr',
#   'desc': 'Good knowledge of JBOSS, Node.JS, VDB and ETL tools. Experience in developing/customizing applications using Java, .Net, Python, R etc....',
#   'age': '7 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:11'},
#  {'jkid': '8b072c77f8192d66',
#   'company': 'Halliburton',
#   'jcid': '0e4554ac6dcff427',
#   'loc': 'Houston, TX 77032',
#   'job_no': 2,
#   'title': 'Sr. Data Engineer - Petrophysical Applications',
#   'desc': 'Strong knowledge of relational databases such as Oracle, MySQL, Microsoft SQL server, Postgres SQL. Strong scripting ability in bash and/or Python....',
#   'age': '12 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:11'},
#  {'jkid': 'b2a0bd7b35b6528c',
#   'company': 'Halliburton',
#   'jcid': '0e4554ac6dcff427',
#   'loc': 'Houston, TX 77032',
#   'job_no': 3,
#   'title': 'Data Scientist',
#   'desc': 'Minimum of 3 year experience in building classification or regression models using R or Python. This covered backend data processing skills including...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:11'},
#  {'jkid': '2e81502165ebd484',
#   'company': 'Halliburton',
#   'jcid': '0e4554ac6dcff427',
#   'loc': 'Houston, TX 77032',
#   'job_no': 4,
#   'title': 'DevOps/Configuration Management Engineer',
#   'desc': 'Python, Powershell, JSON, JavaScript). We are looking for the right people — people who want to innovate, achieve, grow and lead....',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:11'},
#  {'jkid': 'e29ff26b5a023740',
#   'company': 'Cummins Inc.',
#   'jcid': '6b27921c22410a0e',
#   'loc': 'Columbus, IN',
#   'job_no': 1,
#   'title': 'Senior Software Developer',
#   'desc': 'Proficiency in, at least, one modern programming language such as C, C++, Objective C, or Java, Python. Cummins is a place big enough to coach and develop a...',
#   'age': '6 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:14'},
#  {'jkid': '34d6616433b72e11',
#   'company': 'Cummins Inc.',
#   'jcid': '6b27921c22410a0e',
#   'loc': 'Columbus, IN',
#   'job_no': 2,
#   'title': 'Software Engineering Leader',
#   'desc': 'Proficiency in, at least, one modern programming language such as C, C , Objective C, or Java, Python. Cummins is a place big enough to coach and develop a...',
#   'age': '10 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:14'},
#  {'jkid': '71ba992df5bd55e0',
#   'company': 'Cummins Inc.',
#   'jcid': '6b27921c22410a0e',
#   'loc': 'Columbus, IN',
#   'job_no': 3,
#   'title': 'Software Engineering Team Lead',
#   'desc': 'Proficiency in, at least, one modern programming language such as C, C++, Objective C, or Java, Python. Cummins is a place big enough to coach and develop a...',
#   'age': '11 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:14'},
#  {'jkid': '1bcaa9bf3714abc9',
#   'company': 'Cummins Inc.',
#   'jcid': '6b27921c22410a0e',
#   'loc': 'Columbus, IN',
#   'job_no': 4,
#   'title': 'Software License Analyst',
#   'desc': 'SQL database, Microsoft IIS, PowerShell, Windows and Unix (Solaris10)/Linux platform familiarity preferred. Cummins is a place big enough to coach and develop a...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:14'},
#  {'jkid': 'aed752a2b554ab2c',
#   'company': 'Cummins Power Systems, LLC.',
#   'jcid': '02fad34b323f13f7',
#   'loc': 'Columbus, IN',
#   'job_no': 5,
#   'title': 'DevOps Engineer',
#   'desc': 'Knowledge of SQL databases ( Oracle or MS SQL) a plus. Cummins is a place big enough to coach and develop a global workforce and create the world’s leading...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:14'},
#  {'jkid': 'c9a6cc8276891502',
#   'company': 'Cummins Inc.',
#   'jcid': '6b27921c22410a0e',
#   'loc': 'Columbus, IN',
#   'job_no': 6,
#   'title': 'Software Engineering Lead',
#   'desc': 'Proficiency in, at least, one modern programming language such as C, C , Objective C, or Java, Python. Cummins is a place big enough to coach and develop a...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:14'},
#  {'jkid': '754b99fd8eac9e44',
#   'company': 'Cummins Inc.',
#   'jcid': '6b27921c22410a0e',
#   'loc': 'Columbus, IN',
#   'job_no': 7,
#   'title': 'Senior Software Engineer',
#   'desc': 'Proficiency in, at least, one modern programming language such as C, C , Objective C, or Java, Python. Cummins is a place big enough to coach and develop a...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:14'},
#  {'jkid': '2a27825fcbb0b3ed',
#   'company': 'Cummins Inc.',
#   'jcid': '6b27921c22410a0e',
#   'loc': 'Columbus, IN',
#   'job_no': 8,
#   'title': 'Principal Data Scientist',
#   'desc': 'Cummins is a place big enough to coach and develop a global workforce and create the world’s leading clean, engine technology. We’re also small enough for you...',
#   'age': '30+ days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:14'},
#  {'jkid': '6cea7f0a37534ed7',
#   'company': 'Advanced Micro Devices, Inc.',
#   'jcid': '14872b5be04c1bd6',
#   'loc': 'Austin, TX',
#   'job_no': 1,
#   'title': 'SQA Lead 66608',
#   'desc': 'As the primary gatekeeper for firmware that goes out to customers, you need to identify the highest risks and work with the development team to get them...',
#   'age': '1 day ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:15'},
#  {'jkid': '02bbb43b8235c2d1',
#   'company': 'Advanced Micro Devices, Inc.',
#   'jcid': '14872b5be04c1bd6',
#   'loc': 'Austin, TX',
#   'job_no': 2,
#   'title': 'Firmware Applications Engineer 66946',
#   'desc': 'In this position you will develop applications to demonstrate our wireless devices; develop and support internal development tools; author internal design...',
#   'age': '1 day ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:15'},
#  {'jkid': 'a2e24ff20379bd8f',
#   'company': 'Advanced Micro Devices, Inc.',
#   'jcid': '14872b5be04c1bd6',
#   'loc': 'Austin, TX',
#   'job_no': 3,
#   'title': 'Tools Engineer / Lead 66875',
#   'desc': 'In this position, you will be responsible for developing customer facing tool(s) that run on Linux/PC and will be used to download, configure and tune...',
#   'age': '1 day ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:15'},
#  {'jkid': '83da170851157f6d',
#   'company': 'Advanced Micro Devices, Inc.',
#   'jcid': '14872b5be04c1bd6',
#   'loc': 'Austin, TX',
#   'job_no': 4,
#   'title': 'SOC Lead Validation Engineer 66784',
#   'desc': 'This validation role, in coordination with the design team, will develop and execute validation testing on our 60 GHz wireless SoC. The ideal candidate...',
#   'age': '1 day ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:15'},
#  {'jkid': '12e52025585a64b4',
#   'company': 'Advanced Micro Devices, Inc.',
#   'jcid': '14872b5be04c1bd6',
#   'loc': 'Bellevue, WA',
#   'job_no': 5,
#   'title': 'Field Application Engineer (GPU) - Seattle - 56925',
#   'desc': 'Solutions Architects help AMD drive a new era of computing into the datacenter by engaging with key end users and independent software partners to...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:15'},
#  {'jkid': '73f5e548be2b3d79',
#   'company': 'Advanced Micro Devices, Inc.',
#   'jcid': '14872b5be04c1bd6',
#   'loc': 'Austin, TX',
#   'job_no': 6,
#   'title': 'Hardware Applications Engineer',
#   'desc': 'In this position you will develop PCBs for internal testing and external demonstrations; assist other team members with HW testing and lab work; author...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:15'},
#  {'jkid': 'a9cf2846b9555673',
#   'company': 'Advanced Micro Devices, Inc.',
#   'jcid': '14872b5be04c1bd6',
#   'loc': 'Austin, TX',
#   'job_no': 7,
#   'title': 'Microprocessor Verification Engineer - SW Tools (#65784)',
#   'desc': 'Member of a cross-site team owning development, enhancement, and deployment of AMD Architectural Verification Tools, including Random Instruction Generators...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:15'},
#  {'jkid': '149e388efb0a2792',
#   'company': 'Advanced Micro Devices, Inc.',
#   'jcid': '14872b5be04c1bd6',
#   'loc': 'Santa Clara, CA',
#   'job_no': 8,
#   'title': 'Senior Staff SerDes/RTL Design Engineer (70250)',
#   'desc': 'The SerDes RTL team is looking for passionate and experienced Design Engineers for RTL Design and Firmware development of high speed SerDes IPs. You will...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:15'},
#  {'jkid': '04e21dc43f151834',
#   'company': 'Advanced Micro Devices, Inc.',
#   'jcid': '14872b5be04c1bd6',
#   'loc': 'Santa Clara, CA',
#   'job_no': 9,
#   'title': 'Sr. Tools Engineer - 69534',
#   'desc': 'All existing tools SW are open source, and you will have the opportunity to tackle interesting and challenging problems working with open technology stacks...',
#   'age': '4 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:15'},
#  {'jkid': '9c9d3333990a4081',
#   'company': 'Advanced Micro Devices, Inc.',
#   'jcid': '14872b5be04c1bd6',
#   'loc': 'Austin, TX',
#   'job_no': 10,
#   'title': 'Co-Op Engineer - Spring 2019 (69856)',
#   'desc': 'Support overall compatibility, compliance, and test coverage of processors from product definition through product qualification and into high volume...',
#   'age': '5 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:15'},
#  {'jkid': '694592bd1d7ab894',
#   'company': 'Molina Healthcare',
#   'jcid': '61b6afe09a420e77',
#   'loc': 'Long Beach, CA',
#   'job_no': 1,
#   'title': 'Mgr, Healthcare Analytics',
#   'desc': 'Strong knowledge of SQL 2005/2008 SSRS report development. Collects, validates, analyzes, and organizes data into meaningful reports for management decision...',
#   'age': '2 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:17'},
#  {'jkid': 'de304be16fd9ae44',
#   'company': 'Molina Healthcare',
#   'jcid': '61b6afe09a420e77',
#   'loc': 'Long Beach, CA',
#   'job_no': 2,
#   'title': 'Lead Engineer, Applications',
#   'desc': 'Strong SQL queries. 7+ years of hands-on experience in Microsoft technologies including C#, ASP.NET, SQL Server, MVC, WCF, BizTalk, JQuery, web services, SSIS,...',
#   'age': '3 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:17'},
#  {'jkid': 'e08de9bb43424e3b',
#   'company': 'Molina Healthcare',
#   'jcid': '61b6afe09a420e77',
#   'loc': 'Syracuse, NY',
#   'job_no': 3,
#   'title': 'Sr Healthcare Analytics - Syracuse, NY',
#   'desc': 'Basic knowledge of SQL. SQL knowledge and daily working with developing ad-hoc reports using SQL programming, SQL Server Reporting Services (SSRS), Power BI,...',
#   'age': '4 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:17'},
#  {'jkid': 'e431bc4841a29a5d',
#   'company': 'Molina Healthcare',
#   'jcid': '61b6afe09a420e77',
#   'loc': 'Columbus, OH',
#   'job_no': 4,
#   'title': 'Encounters - Sr. Healthcare Finance Analyst (Columbus, OH)',
#   'desc': 'SQL programming, SQL Server Reporting Services (SSRS), PowerBI, Medinsight, RxNavigator,. Basic knowledge of SQL....',
#   'age': '4 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:17'},
#  {'jkid': '0419663ffd852c6c',
#   'company': 'Molina Healthcare',
#   'jcid': '61b6afe09a420e77',
#   'loc': 'Oak Brook, IL',
#   'job_no': 5,
#   'title': 'Analyst, Config Info Mgmt-SQL',
#   'desc': 'Job Summary Responsible for accurate and timely implementation and maintenance of critical information on claims databases. Maintains critical information on...',
#   'age': '6 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:17'},
#  {'jkid': '7dbd5f83dd2446b6',
#   'company': 'Molina Healthcare',
#   'jcid': '61b6afe09a420e77',
#   'loc': 'Long Beach, CA',
#   'job_no': 6,
#   'title': 'Analyst, Data',
#   'desc': 'Analyst, Data - (1806435) Primary Location: US-CA-Long Beach-HUGHES Job: Core Operations Organization: Corporate Job Posting: Oct 22, 2018, 2:37:50 PM...',
#   'age': '7 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:17'},
#  {'jkid': 'ab0e74da16edce83',
#   'company': 'Molina Healthcare',
#   'jcid': '61b6afe09a420e77',
#   'loc': 'Long Beach, CA',
#   'job_no': 7,
#   'title': 'Senior Data Analyst',
#   'desc': 'Strong SQL and Excel skills/background. Designs and implements processes and solutions associated with a wide variety of data sets used for data/text mining,...',
#   'age': '11 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:17'},
#  {'jkid': '6aa3060077c5c200',
#   'company': 'Molina Healthcare',
#   'jcid': '61b6afe09a420e77',
#   'loc': 'Long Beach, CA',
#   'job_no': 8,
#   'title': 'Senior Finance ERP IT Systems Analyst',
#   'desc': 'SQL experience to extract data to design and build the integration. Senior Finance ERP IT Systems Analyst - (1800626)....',
#   'age': '9 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:17'},
#  {'jkid': 'edab318c475c182e',
#   'company': 'Molina Healthcare',
#   'jcid': '61b6afe09a420e77',
#   'loc': 'Midvale, UT',
#   'job_no': 9,
#   'title': 'Mgr, HEDIS Performance Measurement',
#   'desc': "SQL Reporting Services Certification (SRSC). Molina's Quality Improvement function oversees, plans, and implements new and existing healthcare quality...",
#   'age': '20 days ago',
#   'query_date': '2018-10-29',
#   'query_time': '20:50:17'},
#  ...]

# %%
with open('data.json', 'w') as outfile:
    json.dump(jobs, outfile)

# %%
df = pd.DataFrame.from_dict(jobs)

# %%
df.to_csv("indeed.dat")

# %%
type(soup.findAll('a'))

# %%
a

# %%
# another (shorter) method to get url with jcid for company, which I figured out last!
soup=bs(a,'html.parser')
output=soup.a['href']
print(output)

# %%
a.split('"')

# %%
[z.strip() for z in a.split('"')]

# %%
a_list=[z.strip() for z in a.split('"')]

# %%
a_list

# %%
a_list[1].split("jcid=")[1].split('&')

# %%
jcid=a_list[1].split("jcid=")[1].split('&')[0]

# %%
second_url_step="https://www.indeed.com/jobs?q="+ what + "&rbc=" + co + "&jcid=" + jcid + "&sort=date"

# %%
# I DID IT FINALLY !!!! YAH
second_url_step

# %%
html = requests.get(second_url_step)
soup = bs(html.text, 'html.parser')

# %%
html

# %%
soup.find('span', {'class':'location'}).text

# %%
co_string='>'+ top_fortune500[0]+'<'
a_all=soup.findAll('a',rel='nofollow')
for a in a_all:
    a=str(a)
    if 'jcid' in a and co_string in a:
        print(a)

# %%
a
